# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import math
import os
import time
import re
import html

#conda activate my_generic_1

# %%
#ArticleReader
class Article_Reader():
    def __init__(self):
        self.article_data = pd.DataFrame()
        
    def show_headlines(self, num):
        if not self.article_data.empty:
            print(self.article_data[['heading','href']].head(num))
            return
        print("No articles loaded.")
        
    def read_article(self, link):
        try:
            response = requests.get(link['href'])
            soup = BeautifulSoup(response.content, "html.parser")
        except:
            print("Exceptional URL: "+link['href'])
            return 0
        article = soup.find(re.compile("article"))
        bodies_found = 0
        link['text'] = link['heading']
        if article:
            link['text'] += article.text
            return 1
        else:
            article_elems = soup.find("div",class_=re.compile("article"))
            if article_elems is None:
                print("No article found: " +link['href'])
                return 0
            for a in article_elems:
                txt = self.clean_text(a.text)
                # Para limit of 10 words
                para_condition = len(txt.split(' ')) > 10
                if para_condition:
                    link['text'] += txt+' '
            return 1
        print("No article element found.")
        return 0
        
    def check_article(self, heading, link, main_url):
        link['href'] = link['href'] if not link['href'].startswith('/') else main_url+link['href']
        # Heading limit of at least 5 words
        heading_condition = len(heading.split(' '))<5
        if heading_condition:
            return 0
        res = self.read_article(link)
        return res
    
    def clean_text(self, txt):
        _re_space = re.compile(r"\s+")
        txt = _re_space.sub(" ", txt).strip()
        txt = txt.replace('\n',' ')
        return txt
    
    def load_headlines(self, urls):
        for url in urls:
            response = requests.get(url)
            soup = BeautifulSoup(response.content, "html.parser")
            articles = soup.find_all("a", class_=re.compile('head'))
            print("Loading headline articles: ", url)
            print("Found a: "+str(len(articles)))
            # Article limit of at least 5 per home link
            if len(articles) < 20:
                found = soup.find_all('a', href=True)
                articles+=found
                print("Other links found: "+str(len(found)))
                        
            for article in articles:
                article_name = self.clean_text(article.text)
                info_dict={'href':article['href'], 'heading': article_name, 'text':''}
                read = self.check_article(article_name, info_dict, url)
                if read:
                    info_dict = {k:[v] for k,v in info_dict.items()}
                    self.article_data = pd.concat([self.article_data, pd.DataFrame(info_dict)], ignore_index=True)
        return self.article_data
    
    def save_corpus(self, corpus_name, path):
        self.article_data.to_csv(path+corpus_name+'_article_corpus.csv')

# %%
ar = Article_Reader()
output_path = 'output/'
corpus_name = 'financial'
financial_report_links = [
    "https://www.barrons.com",
    "https://www.bloomberg.com",
    "https://www.reuters.com",
    "https://www.ft.com",
    "https://www.marketwatch.com/markets",
    "https://finance.yahoo.com/",
    "https://www.investopedia.com/markets",
    "https://www.economist.com/",
    "https://www.economist.com/weeklyedition/2023-05-20",
    "https://www.theguardian.com/us/business",
    "https://www.theguardian.com/business/stock-markets",
    "https://www.morningstar.com",
    "https://www.fool.com"
]

found_headlines = ar.load_headlines(financial_report_links)
ar.save_corpus(corpus_name, output_path)
ar.show_headlines(5)
# Out:
# Loading headline articles:  https://www.barrons.com
# Found a: 3
# Other links found: 14
# Loading headline articles:  https://www.bloomberg.com
# Found a: 0
# Other links found: 4
# Loading headline articles:  https://www.reuters.com
# Found a: 38
# Loading headline articles:  https://www.ft.com
# Found a: 226
# Loading headline articles:  https://www.marketwatch.com/markets
# Found a: 0
# Other links found: 367
# Loading headline articles:  https://finance.yahoo.com/
# Found a: 21
# Loading headline articles:  https://www.investopedia.com/markets
# Found a: 1
# Other links found: 215
# Exceptional URL: #
# Loading headline articles:  https://www.economist.com/
# Found a: 11
# Other links found: 224
# No article found: https://www.economist.com//weeklyedition/2023-05-20
# No article found: https://www.economist.com//economics-a-to-z/
# No article found: https://www.economist.com//economics-a-to-z/
# No article found: https://www.economist.com//weeklyedition/2023-05-20
# No article found: https://www.economist.com//special-report/2023-05-20
# No article found: https://www.economist.com/privacyportal
# Loading headline articles:  https://www.economist.com/weeklyedition/2023-05-20
# Found a: 1
# Other links found: 234
# No article found: https://www.economist.com/weeklyedition/2023-05-20/leaders/2023/05/18/joe-bidens-global-vision-is-too-timid-and-pessimistic
# No article found: https://www.economist.com/weeklyedition/2023-05-20/leaders/2023/05/18/china-and-the-west-take-a-step-to-ease-africas-debt-crisis
# No article found: https://www.economist.com/weeklyedition/2023-05-20/leaders/2023/05/18/the-humiliation-of-thailands-regime-is-a-boost-for-asian-democracy
# No article found: https://www.economist.com/weeklyedition/2023-05-20/leaders/2023/05/18/the-fight-over-the-future-of-global-payments
# No article found: https://www.economist.com/weeklyedition/2023-05-20/leaders/2023/05/18/trade-in-dinosaur-fossils-is-good-for-science
# No article found: https://www.economist.com/weeklyedition/2023-05-20/by-invitation/2023/05/15/tedros-adhanom-head-of-the-who-on-the-lessons-from-covid-19
# No article found: https://www.economist.com/weeklyedition/2023-05-20/by-invitation/2023/05/18/abebe-aemro-selassie-on-africas-brutal-funding-squeeze
# No article found: https://www.economist.com/weeklyedition/2023-05-20/briefing/2023/05/17/henry-kissinger-explains-how-to-avoid-world-war-three
# No article found: https://www.economist.com/weeklyedition/2023-05-20/united-states/2023/05/16/the-fault-lines-in-americas-china-policy
# No article found: https://www.economist.com/weeklyedition/2023-05-20/united-states/2023/05/17/what-do-george-santos-r-kelly-and-fifa-have-in-common
# No article found: https://www.economist.com/weeklyedition/2023-05-20/united-states/2023/05/14/pinball-is-booming-in-america-thanks-to-nostalgia-and-canny-marketing
# No article found: https://www.economist.com/weeklyedition/2023-05-20/united-states/2023/05/18/anoint-my-caverns-with-oil
# No article found: https://www.economist.com/weeklyedition/2023-05-20/united-states/2023/05/18/congress-should-fund-the-blm-no-not-that-one
# No article found: https://www.economist.com/weeklyedition/2023-05-20/united-states/2023/05/18/san-franciscos-woke-maths-experiment
# No article found: https://www.economist.com/weeklyedition/2023-05-20/united-states/2023/05/18/it-turns-out-that-democrats-bus-migrants-too
# No article found: https://www.economist.com/weeklyedition/2023-05-20/the-americas/2023/05/18/latin-americas-left-wing-experiment-is-a-warning-to-the-world
# No article found: https://www.economist.com/weeklyedition/2023-05-20/the-americas/2023/05/18/ecuadors-president-dissolves-congress-to-avoid-impeachment
# No article found: https://www.economist.com/weeklyedition/2023-05-20/asia/2023/05/16/can-the-west-win-over-the-rest-of-the-world
# No article found: https://www.economist.com/weeklyedition/2023-05-20/asia/2023/05/18/the-taliban-go-big-on-animal-welfare
# No article found: https://www.economist.com/weeklyedition/2023-05-20/asia/2023/05/15/thailands-pro-democracy-parties-trounce-the-military-establishment
# No article found: https://www.economist.com/weeklyedition/2023-05-20/asia/2023/05/14/narendra-modis-party-takes-a-beating-in-karnataka
# No article found: https://www.economist.com/weeklyedition/2023-05-20/asia/2023/05/18/myanmars-conflict-is-dividing-south-east-asia
# No article found: https://www.economist.com/weeklyedition/2023-05-20/china/2023/05/18/china-is-unusually-secretive-about-its-space-programme
# No article found: https://www.economist.com/weeklyedition/2023-05-20/china/2023/05/18/xiongan-is-xi-jinpings-pet-project
# No article found: https://www.economist.com/weeklyedition/2023-05-20/middle-east-and-africa/2023/05/18/irans-proxies-in-the-middle-east-remain-a-powerful-force
# No article found: https://www.economist.com/weeklyedition/2023-05-20/middle-east-and-africa/2023/05/18/americas-new-embassy-in-beirut-is-vast
# No article found: https://www.economist.com/weeklyedition/2023-05-20/middle-east-and-africa/2023/05/18/looking-for-the-african-middle-class-head-to-the-bus-park
# No article found: https://www.economist.com/weeklyedition/2023-05-20/middle-east-and-africa/2023/05/18/foreign-airlines-in-nigeria-are-frustrated-by-the-blocking-of-their-funds
# No article found: https://www.economist.com/weeklyedition/2023-05-20/middle-east-and-africa/2023/05/16/africa-faces-a-mounting-debt-crisis
# No article found: https://www.economist.com/weeklyedition/2023-05-20/europe/2023/05/14/recep-tayyip-erdogan-beats-his-challenger-as-turkey-votes
# No article found: https://www.economist.com/weeklyedition/2023-05-20/europe/2023/05/18/volodymyr-zelenskys-european-trip-secures-a-lot-more-military-backing
# No article found: https://www.economist.com/weeklyedition/2023-05-20/europe/2023/05/17/how-a-front-line-city-became-ukraines-romantic-capital
# No article found: https://www.economist.com/weeklyedition/2023-05-20/europe/2023/05/18/fears-about-the-reactors-at-zaporizhia-continue-to-mount
# No article found: https://www.economist.com/weeklyedition/2023-05-20/europe/2023/05/18/for-giorgia-meloni-supporting-ukraine-has-some-useful-benefits
# No article found: https://www.economist.com/weeklyedition/2023-05-20/europe/2023/05/18/meet-the-lefty-europeans-who-want-to-deliberately-shrink-the-economy
# No article found: https://www.economist.com/weeklyedition/2023-05-20/britain/2023/05/18/britains-public-order-act-goes-too-far
# No article found: https://www.economist.com/weeklyedition/2023-05-20/britain/2023/05/15/why-are-more-british-adults-still-living-with-their-parents
# No article found: https://www.economist.com/weeklyedition/2023-05-20/britain/2023/05/16/the-inflation-reduction-act-is-turning-heads-among-british-businesses
# No article found: https://www.economist.com/weeklyedition/2023-05-20/britain/2023/05/18/the-missing-ingredient-in-britains-new-law-on-tenants-rights
# No article found: https://www.economist.com/weeklyedition/2023-05-20/britain/2023/05/18/aboard-britains-first-commercial-self-driving-bus
# No article found: https://www.economist.com/weeklyedition/2023-05-20/britain/2023/05/18/want-to-be-a-nun-you-need-to-pass-these-tests
# No article found: https://www.economist.com/weeklyedition/2023-05-20/international/2023/05/15/europe-cant-decide-how-to-unplug-from-china
# No article found: https://www.economist.com/weeklyedition/2023-05-20/special-report/2023/05/15/as-payments-systems-go-digital-they-are-changing-global-finance
# No article found: https://www.economist.com/weeklyedition/2023-05-20/special-report/2023/05/15/a-digital-payments-revolution-in-india
# No article found: https://www.economist.com/weeklyedition/2023-05-20/special-report/2023/05/15/the-old-bank/card-model-is-still-entrenched-in-the-rich-world
# No article found: https://www.economist.com/weeklyedition/2023-05-20/special-report/2023/05/15/the-promise-of-crypto-has-not-lived-up-to-its-initial-excitement
# No article found: https://www.economist.com/weeklyedition/2023-05-20/special-report/2023/05/15/central-bank-digital-currencies-are-talked-about-more-than-coming-to-fruition
# No article found: https://www.economist.com/weeklyedition/2023-05-20/special-report/2023/05/15/could-digital-payments-systems-help-unseat-the-dollar
# No article found: https://www.economist.com/weeklyedition/2023-05-20/special-report/2023/05/15/there-are-risks-but-also-big-potential-benefits-from-digital-payments
# No article found: https://www.economist.com/weeklyedition/2023-05-20/special-report/2023/05/16/video-insights-from-the-author
# No article found: https://www.economist.com/weeklyedition/2023-05-20/business/2023/05/16/businesses-are-in-for-a-mighty-debt-hangover
# No article found: https://www.economist.com/weeklyedition/2023-05-20/business/2023/05/14/the-aviation-industry-wants-to-be-net-zero-but-not-yet
# No article found: https://www.economist.com/weeklyedition/2023-05-20/business/2023/05/18/the-wind-turbine-industry-should-be-booming-why-isnt-it
# No article found: https://www.economist.com/weeklyedition/2023-05-20/business/2023/05/18/mukesh-ambani-returns-to-the-spotlight
# No article found: https://www.economist.com/weeklyedition/2023-05-20/business/2023/05/18/americas-culture-wars-threaten-its-single-market
# No article found: https://www.economist.com/weeklyedition/2023-05-20/finance-and-economics/2023/05/18/the-financial-system-is-slipping-into-state-control
# No article found: https://www.economist.com/weeklyedition/2023-05-20/finance-and-economics/2023/05/15/what-america-does-after-a-debt-ceiling-disaster
# No article found: https://www.economist.com/weeklyedition/2023-05-20/finance-and-economics/2023/05/18/is-chinas-recovery-about-to-stall
# No article found: https://www.economist.com/weeklyedition/2023-05-20/finance-and-economics/2023/05/18/libor-will-at-last-be-switched-off-in-june
# No article found: https://www.economist.com/weeklyedition/2023-05-20/finance-and-economics/2023/05/17/how-to-invest-in-artificial-intelligence
# No article found: https://www.economist.com/weeklyedition/2023-05-20/finance-and-economics/2023/05/18/robert-lucas-was-a-giant-of-macroeconomics
# No article found: https://www.economist.com/weeklyedition/2023-05-20/science-and-technology/2023/05/17/the-market-for-dinosaur-fossils-is-booming
# No article found: https://www.economist.com/weeklyedition/2023-05-20/science-and-technology/2023/05/17/artists-hope-to-turn-selfies-into-comets
# No article found: https://www.economist.com/weeklyedition/2023-05-20/science-and-technology/2023/05/17/humans-shed-genetic-information-everywhere-they-go
# No article found: https://www.economist.com/weeklyedition/2023-05-20/science-and-technology/2023/05/17/the-coming-years-will-be-the-hottest-ever
# No article found: https://www.economist.com/weeklyedition/2023-05-20/science-and-technology/2023/05/17/insects-could-help-turn-beer-waste-into-beef
# No article found: https://www.economist.com/weeklyedition/2023-05-20/culture/2023/05/18/in-1983-arthur-miller-directed-one-of-his-best-known-plays-in-china
# No article found: https://www.economist.com/weeklyedition/2023-05-20/culture/2023/05/17/fancy-bear-goes-phishing-charts-the-evolution-of-hacking
# No article found: https://www.economist.com/weeklyedition/2023-05-20/culture/2023/05/18/in-emma-clines-new-novel-a-young-woman-loses-control-of-her-life
# No article found: https://www.economist.com/weeklyedition/2023-05-20/culture/2023/05/18/wings-v-tenders-the-choice-says-more-about-you-than-you-think
# No article found: https://www.economist.com/weeklyedition/2023-05-20/culture/2023/05/18/in-fatherland-an-author-reckons-with-his-nazi-grandfather
# No article found: https://www.economist.com/weeklyedition/2023-05-20/culture/2023/05/18/quiet-artworks-sometimes-make-the-deepest-impressions
# No article found: https://www.economist.com/weeklyedition/2023-05-20/economic-and-financial-indicators/2023/05/18/economic-data-commodities-and-markets
# No article found: https://www.economist.com/weeklyedition/2023-05-20/graphic-detail/2023/05/16/sacking-tucker-carlson-has-put-a-dent-in-fox-newss-ratings
# No article found: https://www.economist.com/weeklyedition/2023-05-20/obituary/2023/05/18/pema-tseden-was-the-founder-and-builder-of-tibetan-cinema
# No article found: https://www.economist.com/weeklyedition/2023-05-20/the-economist-reads/2023/05/16/what-to-read-about-villains-in-business
# No article found: https://www.economist.com/privacyportal
# Loading headline articles:  https://www.theguardian.com/us/business
# Found a: 32
# Loading headline articles:  https://www.theguardian.com/business/stock-markets
# Found a: 21
# Loading headline articles:  https://www.morningstar.com
# Found a: 0
# Other links found: 358
# Loading headline articles:  https://www.fool.com
# Found a: 0
# Other links found: 271
# No article found: https://www.fool.com/the-ascent/credit-cards/bad-credit/
# No article found: https://www.fool.com/the-ascent/mortgages/best-mortgage-lenders-first-time-homebuyers/
# No article found: https://caps.fool.com/
# No article found: https://www.fool.com/the-ascent/credit-cards/bad-credit/
# No article found: https://www.fool.com/the-ascent/mortgages/best-mortgage-lenders-first-time-homebuyers/
# No article found: https://caps.fool.com/
# No article found: https://www.fool.com/data-protection/ccpa-update/
#                                              heading
# 0  Tesla Stock's Twitter Overhang Is Gone. Here's...  \
# 1  The FTC Is Coming Down Hard on Deal Making. Wh...
# 2  Berkshire Buys Still Get a Buffett Bounce—but ...
# 3  Tesla Stock's Twitter Overhang Is Gone. Here's...
# 4  The FTC Is Coming Down Hard on Deal Making. Wh...
#
#                                                 href
# 0  https://www.barrons.com/articles/tesla-stock-p...
# 1  https://www.barrons.com/articles/washington-de...
# 2  https://www.barrons.com/articles/berkshire-sto...
# 3  https://www.barrons.com/articles/tesla-stock-p...
# 4  https://www.barrons.com/articles/washington-de...

# %%
print("Article Corpus Size: "+str(found_headlines.shape[0]))
found_headlines.head()
# Out:
# Article Corpus Size: 446
#                                                 href
# 0  https://www.barrons.com/articles/tesla-stock-p...  \
# 1  https://www.barrons.com/articles/washington-de...
# 2  https://www.barrons.com/articles/berkshire-sto...
# 3  https://www.barrons.com/articles/tesla-stock-p...
# 4  https://www.barrons.com/articles/washington-de...
#
#                                              heading
# 0  Tesla Stock's Twitter Overhang Is Gone. Here's...  \
# 1  The FTC Is Coming Down Hard on Deal Making. Wh...
# 2  Berkshire Buys Still Get a Buffett Bounce—but ...
# 3  Tesla Stock's Twitter Overhang Is Gone. Here's...
# 4  The FTC Is Coming Down Hard on Deal Making. Wh...
#
#                                                 text
# 0  Tesla Stock's Twitter Overhang Is Gone. Here's...
# 1  The FTC Is Coming Down Hard on Deal Making. Wh...
# 2  Berkshire Buys Still Get a Buffett Bounce—but ...
# 3  Tesla Stock's Twitter Overhang Is Gone. Here's...
# 4  The FTC Is Coming Down Hard on Deal Making. Wh...
