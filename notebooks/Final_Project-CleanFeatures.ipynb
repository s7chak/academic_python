# %%
from selenium import webdriver
import pandas as pd
import numpy as np
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import spacy
import en_core_web_lg
import datetime
from dateutil.parser import parse

# %% [markdown]
# ### PART A - Extracing Book Reviews

# %%
### Scraping book reviewa via Selenium ###

driver = webdriver.Chrome(executable_path='/Users/livestrong19/Downloads/chromedriver')
driver.get('https://www.goodreads.com/list/show/264.Books_That_Everyone_Should_Read_At_Least_Once')

### Fetch names of 100 books and URL link

book_dict={}
for i in range(1,101):
    book_path=driver.find_element_by_xpath('//div[@id="all_votes"]/table/tbody/tr['+str(i)+']/td[3]/a')
    book_name=driver.find_element_by_xpath('//div[@id="all_votes"]/table/tbody/tr['+str(i)+']/td[3]/a/span').text
    book_dict[book_name]=book_path.get_attribute('href')
driver.close()

# %%
book_dict
# Out:
# {'To Kill a Mockingbird (To Kill a Mockingbird, #1)': 'https://www.goodreads.com/book/show/2657.To_Kill_a_Mockingbird',
#  "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)": 'https://www.goodreads.com/book/show/3.Harry_Potter_and_the_Sorcerer_s_Stone',
#  '1984': 'https://www.goodreads.com/book/show/5470.1984',
#  'Pride and Prejudice': 'https://www.goodreads.com/book/show/1885.Pride_and_Prejudice',
#  'The Diary of a Young Girl': 'https://www.goodreads.com/book/show/48855.The_Diary_of_a_Young_Girl',
#  'The Little Prince': 'https://www.goodreads.com/book/show/157993.The_Little_Prince',
#  'The Great Gatsby': 'https://www.goodreads.com/book/show/4671.The_Great_Gatsby',
#  'The Catcher in the Rye': 'https://www.goodreads.com/book/show/5107.The_Catcher_in_the_Rye',
#  'Animal Farm': 'https://www.goodreads.com/book/show/14060211-animal-farm',
#  'The Lord of the Rings (The Lord of the Rings, #1-3)': 'https://www.goodreads.com/book/show/33.The_Lord_of_the_Rings',
#  'Jane Eyre': 'https://www.goodreads.com/book/show/10210.Jane_Eyre',
#  'The Book Thief': 'https://www.goodreads.com/book/show/19063.The_Book_Thief',
#  'The Chronicles of Narnia (Chronicles of Narnia, #1-7)': 'https://www.goodreads.com/book/show/11127.The_Chronicles_of_Narnia',
#  'Romeo and Juliet': 'https://www.goodreads.com/book/show/18135.Romeo_and_Juliet',
#  'Lord of the Flies': 'https://www.goodreads.com/book/show/7624.Lord_of_the_Flies',
#  'Harry Potter and the Deathly Hallows (Harry Potter, #7)': 'https://www.goodreads.com/book/show/136251.Harry_Potter_and_the_Deathly_Hallows',
#  'The Kite Runner': 'https://www.goodreads.com/book/show/77203.The_Kite_Runner',
#  'The Giver (The Giver, #1)': 'https://www.goodreads.com/book/show/3636.The_Giver',
#  'The Giving Tree': 'https://www.goodreads.com/book/show/370493.The_Giving_Tree',
#  "Charlotte's Web": 'https://www.goodreads.com/book/show/24178.Charlotte_s_Web',
#  'Green Eggs and Ham': 'https://www.goodreads.com/book/show/23772.Green_Eggs_and_Ham',
#  'The Hobbit, or There and Back Again': 'https://www.goodreads.com/book/show/5907.The_Hobbit_or_There_and_Back_Again',
#  'Little Women': 'https://www.goodreads.com/book/show/1934.Little_Women',
#  'Of Mice and Men': 'https://www.goodreads.com/book/show/890.Of_Mice_and_Men',
#  'The Hunger Games (The Hunger Games, #1)': 'https://www.goodreads.com/book/show/2767052-the-hunger-games',
#  'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)': 'https://www.goodreads.com/book/show/5.Harry_Potter_and_the_Prisoner_of_Azkaban',
#  "Alice's Adventures in Wonderland & Through the Looking-Glass": 'https://www.goodreads.com/book/show/24213.Alice_s_Adventures_in_Wonderland_Through_the_Looking_Glass',
#  'Fahrenheit 451': 'https://www.goodreads.com/book/show/13079982-fahrenheit-451',
#  'Wuthering Heights': 'https://www.goodreads.com/book/show/6185.Wuthering_Heights',
#  'Gone with the Wind': 'https://www.goodreads.com/book/show/18405.Gone_with_the_Wind',
#  'Night (The Night Trilogy, #1)': 'https://www.goodreads.com/book/show/1617.Night',
#  'The Picture of Dorian Gray': 'https://www.goodreads.com/book/show/5297.The_Picture_of_Dorian_Gray',
#  'Holy Bible: King James Version': 'https://www.goodreads.com/book/show/1923820.Holy_Bible',
#  'Harry Potter and the Goblet of Fire (Harry Potter, #4)': 'https://www.goodreads.com/book/show/6.Harry_Potter_and_the_Goblet_of_Fire',
#  'Tolkien on Fairy-stories': 'https://www.goodreads.com/book/show/1362112.Tolkien_on_Fairy_stories',
#  "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy, #1)": 'https://www.goodreads.com/book/show/386162.The_Hitchhiker_s_Guide_to_the_Galaxy',
#  'Hamlet': 'https://www.goodreads.com/book/show/1420.Hamlet',
#  'The Adventures of Huckleberry Finn': 'https://www.goodreads.com/book/show/2956.The_Adventures_of_Huckleberry_Finn',
#  'Harry Potter and the Half-Blood Prince (Harry Potter, #6)': 'https://www.goodreads.com/book/show/1.Harry_Potter_and_the_Half_Blood_Prince',
#  'Les Misérables': 'https://www.goodreads.com/book/show/24280.Les_Mis_rables',
#  'Brave New World / Brave New World Revisited': 'https://www.goodreads.com/book/show/5479.Brave_New_World_Brave_New_World_Revisited',
#  'The Alchemist': 'https://www.goodreads.com/book/show/18144590-the-alchemist',
#  'Crime and Punishment': 'https://www.goodreads.com/book/show/7144.Crime_and_Punishment',
#  'The Secret Garden': 'https://www.goodreads.com/book/show/2998.The_Secret_Garden',
#  'Memoirs of a Geisha': 'https://www.goodreads.com/book/show/929.Memoirs_of_a_Geisha',
#  'The Help': 'https://www.goodreads.com/book/show/4667024-the-help',
#  'The Lion, the Witch and the Wardrobe (Chronicles of Narnia, #1)': 'https://www.goodreads.com/book/show/100915.The_Lion_the_Witch_and_the_Wardrobe',
#  'The Odyssey': 'https://www.goodreads.com/book/show/1381.The_Odyssey',
#  'The Cat in the Hat': 'https://www.goodreads.com/book/show/233093.The_Cat_in_the_Hat',
#  'A Christmas Carol': 'https://www.goodreads.com/book/show/5326.A_Christmas_Carol',
#  'The Outsiders': 'https://www.goodreads.com/book/show/231804.The_Outsiders',
#  'The Color Purple': 'https://www.goodreads.com/book/show/11486.The_Color_Purple',
#  'The Grapes of Wrath': 'https://www.goodreads.com/book/show/18114322-the-grapes-of-wrath',
#  'One Hundred Years of Solitude': 'https://www.goodreads.com/book/show/320.One_Hundred_Years_of_Solitude',
#  'Where the Sidewalk Ends': 'https://www.goodreads.com/book/show/30119.Where_the_Sidewalk_Ends',
#  'A Thousand Splendid Suns': 'https://www.goodreads.com/book/show/128029.A_Thousand_Splendid_Suns',
#  'Where the Wild Things Are': 'https://www.goodreads.com/book/show/19543.Where_the_Wild_Things_Are',
#  'Anne of Green Gables (Anne of Green Gables, #1)': 'https://www.goodreads.com/book/show/8127.Anne_of_Green_Gables',
#  "Ender's Game (Ender's Saga, #1)": 'https://www.goodreads.com/book/show/375802.Ender_s_Game',
#  'The Adventures of Tom Sawyer': 'https://www.goodreads.com/book/show/24583.The_Adventures_of_Tom_Sawyer',
#  'A Tale of Two Cities': 'https://www.goodreads.com/book/show/1953.A_Tale_of_Two_Cities',
#  'Life of Pi': 'https://www.goodreads.com/book/show/4214.Life_of_Pi',
#  'The Count of Monte Cristo': 'https://www.goodreads.com/book/show/7126.The_Count_of_Monte_Cristo',
#  "One Flew Over the Cuckoo's Nest": 'https://www.goodreads.com/book/show/332613.One_Flew_Over_the_Cuckoo_s_Nest',
#  "Oh, the Places You'll Go!": 'https://www.goodreads.com/book/show/191139.Oh_the_Places_You_ll_Go_',
#  'Anna Karenina': 'https://www.goodreads.com/book/show/15823480-anna-karenina',
#  'Winnie-the-Pooh (Winnie-the-Pooh, #1)': 'https://www.goodreads.com/book/show/99107.Winnie_the_Pooh',
#  'Flowers for Algernon': 'https://www.goodreads.com/book/show/18373.Flowers_for_Algernon',
#  'Tuesdays with Morrie': 'https://www.goodreads.com/book/show/6900.Tuesdays_with_Morrie',
#  'Frankenstein': 'https://www.goodreads.com/book/show/35031085-frankenstein',
#  'The Fellowship of the Ring (The Lord of the Rings, #1)': 'https://www.goodreads.com/book/show/34.The_Fellowship_of_the_Ring',
#  'Slaughterhouse-Five': 'https://www.goodreads.com/book/show/4981.Slaughterhouse_Five',
#  'Catch-22 (Catch-22, #1)': 'https://www.goodreads.com/book/show/168668.Catch_22',
#  "The Handmaid's Tale (The Handmaid's Tale, #1)": 'https://www.goodreads.com/book/show/38447.The_Handmaid_s_Tale',
#  'The Old Man and the Sea': 'https://www.goodreads.com/book/show/2165.The_Old_Man_and_the_Sea',
#  'The Scarlet Letter': 'https://www.goodreads.com/book/show/12296.The_Scarlet_Letter',
#  'Macbeth': 'https://www.goodreads.com/book/show/8852.Macbeth',
#  'Twilight (Twilight, #1)': 'https://www.goodreads.com/book/show/41865.Twilight',
#  "The Time Traveler's Wife": 'https://www.goodreads.com/book/show/18619684-the-time-traveler-s-wife',
#  'Lolita': 'https://www.goodreads.com/book/show/7604.Lolita',
#  'Siddhartha': 'https://www.goodreads.com/book/show/52036.Siddhartha',
#  'The Metamorphosis': 'https://www.goodreads.com/book/show/485894.The_Metamorphosis',
#  'The Stranger': 'https://www.goodreads.com/book/show/49552.The_Stranger',
#  'Goodnight Moon': 'https://www.goodreads.com/book/show/32929.Goodnight_Moon',
#  'A Tree Grows in Brooklyn': 'https://www.goodreads.com/book/show/14891.A_Tree_Grows_in_Brooklyn',
#  'War and Peace': 'https://www.goodreads.com/book/show/656.War_and_Peace',
#  'The Little House Collection (Little House, #1-9)': 'https://www.goodreads.com/book/show/114345.The_Little_House_Collection',
#  'A Clockwork Orange': 'https://www.goodreads.com/book/show/227463.A_Clockwork_Orange',
#  'Harry Potter and the Chamber of Secrets (Harry Potter, #2)': 'https://www.goodreads.com/book/show/15881.Harry_Potter_and_the_Chamber_of_Secrets',
#  'The Stand': 'https://www.goodreads.com/book/show/149267.The_Stand',
#  'All Quiet on the Western Front': 'https://www.goodreads.com/book/show/355697.All_Quiet_on_the_Western_Front',
#  "Uncle Tom's Cabin": 'https://www.goodreads.com/book/show/46787.Uncle_Tom_s_Cabin',
#  'Don Quixote': 'https://www.goodreads.com/book/show/3836.Don_Quixote',
#  'Qurʾan / القرآن الكريم': 'https://www.goodreads.com/book/show/646462.Qur_an_',
#  'Atlas Shrugged': 'https://www.goodreads.com/book/show/662.Atlas_Shrugged',
#  'The Brothers Karamazov': 'https://www.goodreads.com/book/show/4934.The_Brothers_Karamazov',
#  'The Poisonwood Bible': 'https://www.goodreads.com/book/show/7244.The_Poisonwood_Bible',
#  'The Book of Mormon: Another Testament of Jesus Christ': 'https://www.goodreads.com/book/show/323355.The_Book_of_Mormon',
#  'Moby-Dick, or, the Whale': 'https://www.goodreads.com/book/show/153747.Moby_Dick_or_the_Whale'}

# %%
### Fetch first 30 reviews for each of the 100 books

book_ratings = pd.DataFrame(columns = ['Book Name','User Rating','Book Review', 'Book Shelf']) 

for key,value in book_dict.items():
    driver = webdriver.Chrome('/Users/livestrong19/Downloads/chromedriver')
    driver.get(value)
    for i in range(1,31):
        try:
            reviews = driver.find_element_by_xpath('//div[@id="bookReviews"]/div['+str(i)+']/div/div/div/div[2]/span/span[2]')
            review_text = reviews.get_attribute('innerHTML')
            rating = driver.find_element_by_xpath('//div[@id="bookReviews"]/div['+str(i)+']/div/div/div/div/span[2]')
            user_rating = rating.get_attribute('title')
            shelf = driver.find_element_by_xpath('//div[@id="bookReviews"]/div['+str(i)+']/div/div/div/div/span[2]')
            shelf = driver.find_elements_by_xpath('//div[@id="bookReviews"]/div['+str(i)+']/div/div/div/div[1]/div/a')
            book_shelf = ""
            for x in range(len(shelf)):
                book_shelf = book_shelf + " " + shelf[x].text
            book_ratings.loc[len(book_ratings)] = [key,user_rating,review_text,book_shelf]
        except:
            pass
    driver.close()

# %%
book_ratings
# Out:
#                                             Book Name      User Rating  \
# 0   To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 1   To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 2   To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 3   To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 4   To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 5   To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 6   To Kill a Mockingbird (To Kill a Mockingbird, #1)  really liked it
# 7   To Kill a Mockingbird (To Kill a Mockingbird, #1)        it was ok
# 8   To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 9   To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 10  To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 11  To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
# 12  To Kill a Mockingbird (To Kill a Mockingbird, #1)  really liked it
# 13  To Kill a Mockingbird (To Kill a Mockingbird, #1)   it was amazing
#
#                                           Book Review  \
# 0   Why is it when I pick up <i> To Kill A Mocking...
# 1   <a href="http://s153.photobucket.com/albums/s2...
# 2   With endless books and infinitely more to be w...
# 3   <b>If you haven't read this as an adult - <u>p...
# 4   To Kill a Mockingbird, Harper Lee<br>To Kill a...
# 5   In the course of 5 years, I’ve read this book ...
# 6   So... I don't really know what to say.<br><br>...
# 7   <b>2.5 stars</b><br><br>Bestseller. Pulitzer P...
# 8   “Until I feared I would lose it, I never loved...
# 9   English (<a href="https://www.goodreads.com/bo...
# 10  I’m not going to do my usual thing where I’d t...
# 11  I looked up Harper Lee online this is her only...
# 12  <b>A short, important, and powerful classic th...
# 13  Life gives you a few things that you can count...
#
#                                            Book Shelf
# 0                             cultured simpatico mmix
# 1    all-time-favorites classics-americas easton-p...
# 2    classics rereads southern-lit pulitzer-winner...
# 3                                           audiobook
# 4    academic novel fiction classic historical 20t...
# 5    american novels literary fiction favorites owned
# 6                                                2015
# 7    disappointing library historical-fiction scho...
# 8
# 9
# 10     postcolonial 2017-10-book-challenge favourites
# 11   made-into-movie classics bookgroup books-i-lo...
# 12
# 13   favorites 2015-reads my-childhood-bookshelves...

# %%
df = pd.read_csv("booksdata.csv")

# %%
df.shape
# Out:
# (31246, 18)

# %%
df.columns
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'bookreview_user',
#        'booktitle', 'bookauthor', 'booksummary', 'booklength', 'books',
#        'books-href', 'bookgenre', 'bookavgrating', 'bookratingcount',
#        'bookcover-src', 'publishdate', 'bookreviewcount', 'bookreview_rating',
#        'bookreview_1', 'bookreview_2'],
#       dtype='object')

# %% [markdown]
# Here `bookreview_2` is just the complete version of `bookreview_1` after clicking on more to see hidden text. For some reviews it may be nan because the review was complete in `bookreview_1` only.

# %% [markdown]
# ### Cleaning Features

# %%
def cleanColumns(train):
    today = datetime.date.today()
    train=df.drop(['web-scraper-order','web-scraper-start-url','books-href','bookreview_user'], axis=1)
    genre=train.bookgenre.apply(lambda x: x.replace('[{"bookgenre":','')) \
                    .apply(lambda x: x.replace('{"bookgenre":','')) \
                    .apply(lambda x: x.replace('}','')) \
                    .apply(lambda x: x.replace(']','')) \
                    .apply(lambda x: x.replace('"',''))

    ratecount=train.bookratingcount.apply(lambda x: int(x.split('\n')[0].strip().replace(',','')))
    reviewcount=train.bookreviewcount.apply(lambda x: int(x.split('\n')[0].strip().replace(',','')))
    published=train.publishdate.apply(lambda x: x.split('\n')[1].replace('th','').replace('rd','').replace('nd','').strip())

    
    train.bookgenre=genre
    train.bookratingcount=ratecount
    train.bookreviewcount=reviewcount
    train.publishdate=published
    delta=train.publishdate.apply(lambda x: int( (today - parse(x).date()).days ))
    train.publishdate=delta
    
    
    return train

# %%
train=df.copy()
train=cleanColumns(train)

# %%
train.head()
# Out:
#                                            booktitle       bookauthor  \
# 0                           The President Is Missing     Bill Clinton
# 1                                      The Institute     Stephen King
# 2      A Higher Loyalty: Truth, Lies, and Leadership      James Comey
# 3  Option B: Facing Adversity, Building Resilienc...  Sheryl Sandberg
# 4                 The Next Person You Meet in Heaven      Mitch Albom
#
#                                          booksummary booklength  books  \
# 0  President Bill Clinton and bestselling novelis...  513 pages     31
# 1  In the middle of the night, in a house on a qu...  561 pages      5
# 2  Former FBI Director James Comey shares his nev...  290 pages     71
# 3  From Facebook's COO and Wharton's top-rated pr...  240 pages     92
# 4  In this enchanting sequel to the number one be...  224 pages     42
#
#                                            bookgenre  bookavgrating  \
# 0        Fiction,Thriller,Mystery,Politics,Audiobook           3.83
# 1    Horror,Fiction,Thriller,Fantasy,Science Fiction           4.23
# 2  Nonfiction,Politics,Autobiography,Memoir,Biogr...           4.18
# 3  Nonfiction,Self Help,Psychology,Autobiography,...           3.87
# 4                 Fiction,Inspirational,Contemporary           4.29
#
#    bookratingcount                                      bookcover-src  \
# 0            73745  https://i.gr-assets.com/images/S/compressed.ph...
# 1            42323  https://i.gr-assets.com/images/S/compressed.ph...
# 2            34983  https://i.gr-assets.com/images/S/compressed.ph...
# 3            39146  https://i.gr-assets.com/images/S/compressed.ph...
# 4            19270  https://i.gr-assets.com/images/S/compressed.ph...
#
#    publishdate  bookreviewcount bookreview_rating  \
# 0          544             8749               NaN
# 1           81             5575    it was amazing
# 2          592             4850         it was ok
# 3          950             3261    it was amazing
# 4          417             2458    it was amazing
#
#                                         bookreview_1  \
# 0  So, you may already know that I like to point ...
# 1  This is the first Stephen King book I’ve ever ...
# 2  Meh... I'm a bit of a news junkie and there wa...
# 3  I have always felt like I was pretty resilient...
# 4  Mitch Albom's sequel is as engaging. Heaven wa...
#
#                                         bookreview_2
# 0  So, you may already know that I like to point ...
# 1  This is the first Stephen King book I’ve ever ...
# 2                                                NaN
# 3  I have always felt like I was pretty resilient...
# 4  Mitch Albom's sequel is as engaging. Heaven wa...

# %% [markdown]
# ## Google Vision Api

# %%
from google.cloud import vision
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "keyFile.json"
image_urls = list_of_urls
ls_of_label_for_url = []

for url in image_urls:
    image_uri = url
    label_list = []
    client = vision.ImageAnnotatorClient()
    image = vision.types.Image()
    image.source.image_uri = image_uri
    response = client.label_detection(image=image)
    print('Labels (and confidence score):')
    print('=' * 79)
    
    for label in response.label_annotations:
        label_list.append(label.description)
        print(f'{label.description} ({label.score*100.:.2f}%)')
    ls_of_label_for_url.append(label_list)
    
print(ls_of_label_for_url)
print('Length of unedited list',len(ls_of_label_for_url))

ls_of_label_for_url = list(filter(None, ls_of_label_for_url))
print(ls_of_label_for_url)
print('Length of edited list', len(ls_of_label_for_url))
