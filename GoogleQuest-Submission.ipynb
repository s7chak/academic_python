# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np
import xgboost as xgb

from sklearn import preprocessing, decomposition, model_selection, metrics, pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import train_test_split, KFold
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.ensemble import AdaBoostRegressor
from xgboost import XGBRegressor, XGBClassifier

from tqdm import tqdm
from sklearn.svm import SVC
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.layers.recurrent import LSTM, GRU
from keras.layers import Dense, Activation, Dropout, Input
from keras.layers.embeddings import Embedding
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
from keras.layers import GlobalMaxPooling1D, Conv1D, MaxPooling1D, Flatten, Bidirectional, SpatialDropout1D
from keras.preprocessing import sequence, text
from keras.callbacks import EarlyStopping, Callback
from keras_radam import RAdam

from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer as sentiment

stop_words = stopwords.words('english')

import seaborn as sns
import matplotlib.pyplot as plt

from scipy.stats import spearmanr
# Out:
# Using TensorFlow backend.

# %%
train = pd.read_csv('input/train.csv')
test = pd.read_csv('input/test.csv')
sample = pd.read_csv('input/sample_submission.csv')

# %%
train.head()
# Out:
#    qa_id                                     question_title  \
# 0      0  What am I losing when using extension tubes in...
# 1      1  What is the distinction between a city and a s...
# 2      2  Maximum protusion length for through-hole comp...
# 3      3              Can an affidavit be used in Beit Din?
# 4      5       How do you make a binary image in Photoshop?
#
#                                        question_body question_user_name  \
# 0  After playing around with macro photography on...               ysap
# 1  I am trying to understand what kinds of places...      russellpierce
# 2  I'm working on a PCB that has through-hole com...          Joe Baker
# 3  An affidavit, from what i understand, is basic...         Scimonster
# 4  I am trying to make a binary image. I want mor...            leigero
#
#                                   question_user_page  \
# 0         https://photo.stackexchange.com/users/1024
# 1           https://rpg.stackexchange.com/users/8774
# 2  https://electronics.stackexchange.com/users/10157
# 3       https://judaism.stackexchange.com/users/5151
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                               answer answer_user_name  \
# 0  I just got extension tubes, so here's the skin...           rfusca
# 1  It might be helpful to look into the definitio...     Erik Schmidt
# 2  Do you even need grooves?  We make several pro...      Dwayne Reid
# 3  Sending an "affidavit" it is a dispute between...    Y     e     z
# 4  Check out Image Trace in Adobe Illustrator. \n...             q2ra
#
#                                     answer_user_page  \
# 0         https://photo.stackexchange.com/users/1917
# 1           https://rpg.stackexchange.com/users/1871
# 2  https://electronics.stackexchange.com/users/64754
# 3       https://judaism.stackexchange.com/users/4794
# 4  https://graphicdesign.stackexchange.com/users/...
#
#                                                  url   category  ...  \
# 0  http://photo.stackexchange.com/questions/9169/...  LIFE_ARTS  ...
# 1  http://rpg.stackexchange.com/questions/47820/w...    CULTURE  ...
# 2  http://electronics.stackexchange.com/questions...    SCIENCE  ...
# 3  http://judaism.stackexchange.com/questions/551...    CULTURE  ...
# 4  http://graphicdesign.stackexchange.com/questio...  LIFE_ARTS  ...
#
#   question_well_written  answer_helpful  answer_level_of_information  \
# 0              1.000000        1.000000                     0.666667
# 1              0.888889        0.888889                     0.555556
# 2              0.777778        0.777778                     0.555556
# 3              0.888889        0.833333                     0.333333
# 4              1.000000        1.000000                     0.666667
#
#    answer_plausible  answer_relevance  answer_satisfaction  \
# 0          1.000000          1.000000             0.800000
# 1          0.888889          0.888889             0.666667
# 2          1.000000          1.000000             0.666667
# 3          0.833333          1.000000             0.800000
# 4          1.000000          1.000000             0.800000
#
#    answer_type_instructions  answer_type_procedure  \
# 0                       1.0               0.000000
# 1                       0.0               0.000000
# 2                       0.0               0.333333
# 3                       0.0               0.000000
# 4                       1.0               0.000000
#
#    answer_type_reason_explanation  answer_well_written
# 0                        0.000000             1.000000
# 1                        0.666667             0.888889
# 2                        1.000000             0.888889
# 3                        1.000000             1.000000
# 4                        1.000000             1.000000
#
# [5 rows x 41 columns]

# %% [markdown]
# ## EDA

# %%
print("Train: ",train.shape)
print("Test: ",test.shape)
print("Sample Sub: ",sample.shape)
# Out:
# Train:  (6079, 41)
# Test:  (476, 11)
# Sample Sub:  (476, 31)

# %%
sample.columns
# Out:
# Index(['qa_id', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written', 'answer_helpful',
#        'answer_level_of_information', 'answer_plausible', 'answer_relevance',
#        'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written'],
#       dtype='object')

# %%
train.columns
# Out:
# Index(['qa_id', 'question_title', 'question_body', 'question_user_name',
#        'question_user_page', 'answer', 'answer_user_name', 'answer_user_page',
#        'url', 'category', 'host', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written', 'answer_helpful',
#        'answer_level_of_information', 'answer_plausible', 'answer_relevance',
#        'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written'],
#       dtype='object')

# %%
train.isnull().sum(axis=0)
# Out:
# qa_id                                    0
# question_title                           0
# question_body                            0
# question_user_name                       0
# question_user_page                       0
# answer                                   0
# answer_user_name                         0
# answer_user_page                         0
# url                                      0
# category                                 0
# host                                     0
# question_asker_intent_understanding      0
# question_body_critical                   0
# question_conversational                  0
# question_expect_short_answer             0
# question_fact_seeking                    0
# question_has_commonly_accepted_answer    0
# question_interestingness_others          0
# question_interestingness_self            0
# question_multi_intent                    0
# question_not_really_a_question           0
# question_opinion_seeking                 0
# question_type_choice                     0
# question_type_compare                    0
# question_type_consequence                0
# question_type_definition                 0
# question_type_entity                     0
# question_type_instructions               0
# question_type_procedure                  0
# question_type_reason_explanation         0
# question_type_spelling                   0
# question_well_written                    0
# answer_helpful                           0
# answer_level_of_information              0
# answer_plausible                         0
# answer_relevance                         0
# answer_satisfaction                      0
# answer_type_instructions                 0
# answer_type_procedure                    0
# answer_type_reason_explanation           0
# answer_well_written                      0
# dtype: int64

# %%
train_columns=train.columns
que_targets = train_columns[11:32]
ans_targets  = train_columns[32:41]
targets=ans_targets.union(que_targets)

# %%
display(train[que_targets].loc[0])
display(train[ans_targets].loc[0])
# Out:
# question_asker_intent_understanding      1.000000
# question_body_critical                   0.333333
# question_conversational                  0.000000
# question_expect_short_answer             0.000000
# question_fact_seeking                    0.000000
# question_has_commonly_accepted_answer    0.000000
# question_interestingness_others          1.000000
# question_interestingness_self            1.000000
# question_multi_intent                    0.000000
# question_not_really_a_question           0.000000
# question_opinion_seeking                 1.000000
# question_type_choice                     0.000000
# question_type_compare                    0.000000
# question_type_consequence                0.000000
# question_type_definition                 0.000000
# question_type_entity                     0.000000
# question_type_instructions               1.000000
# question_type_procedure                  0.000000
# question_type_reason_explanation         0.000000
# question_type_spelling                   0.000000
# question_well_written                    1.000000
# Name: 0, dtype: float64
# answer_helpful                    1.000000
# answer_level_of_information       0.666667
# answer_plausible                  1.000000
# answer_relevance                  1.000000
# answer_satisfaction               0.800000
# answer_type_instructions          1.000000
# answer_type_procedure             0.000000
# answer_type_reason_explanation    0.000000
# answer_well_written               1.000000
# Name: 0, dtype: float64

# %%
train.question_user_name.unique()
# Out:
# array(['ysap', 'russellpierce', 'Joe Baker', ..., 'vsingh', 'Elaine',
#        'Eileen Nehme'], dtype=object)

# %%
plt.figure(figsize=(20, 10))

for i in range(len(que_targets)):
    sns.distplot(train[que_targets[i]], hist= False , rug= False ,kde=True, label =que_targets[i],axlabel =False )


plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
plt.figure(figsize=(20, 10))

for i in range(len(ans_targets)):
    if i not in [2,3]:
        sns.distplot(train[ans_targets[i]], hist= False , rug= False ,kde=True, label =ans_targets[i],axlabel =False )


plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# High frequency
plt.figure(figsize=(20, 10))
sns.distplot(train[ans_targets[2]], hist= False , rug= False ,kde=True, label =ans_targets[2],axlabel =False )
sns.distplot(train[ans_targets[3]], hist= False , rug= False ,kde=True, label =ans_targets[3],axlabel =False )
plt.legend(bbox_to_anchor=(1.02, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
train.groupby('category')[que_targets].mean()
# Out:
#                question_asker_intent_understanding  question_body_critical  \
# category
# CULTURE                                   0.932676                0.668340
# LIFE_ARTS                                 0.950400                0.698323
# SCIENCE                                   0.874240                0.570672
# STACKOVERFLOW                             0.855192                0.524918
# TECHNOLOGY                                0.884724                0.579885
#
#                question_conversational  question_expect_short_answer  \
# category
# CULTURE                       0.122880                      0.737279
# LIFE_ARTS                     0.131641                      0.661730
# SCIENCE                       0.043011                      0.636045
# STACKOVERFLOW                 0.009444                      0.714552
# TECHNOLOGY                    0.038577                      0.703946
#
#                question_fact_seeking  question_has_commonly_accepted_answer  \
# category
# CULTURE                     0.758048                               0.699204
# LIFE_ARTS                   0.679596                               0.646921
# SCIENCE                     0.847359                               0.838008
# STACKOVERFLOW               0.786911                               0.882283
# TECHNOLOGY                  0.776253                               0.815171
#
#                question_interestingness_others  question_interestingness_self  \
# category
# CULTURE                               0.637533                       0.623918
# LIFE_ARTS                             0.665491                       0.625842
# SCIENCE                               0.586567                       0.491897
# STACKOVERFLOW                         0.537288                       0.433316
# TECHNOLOGY                            0.571100                       0.469275
#
#                question_multi_intent  question_not_really_a_question  ...  \
# category                                                              ...
# CULTURE                     0.271893                        0.003634  ...
# LIFE_ARTS                   0.310061                        0.002351  ...
# SCIENCE                     0.269285                        0.003506  ...
# STACKOVERFLOW               0.155760                        0.004655  ...
# TECHNOLOGY                  0.238632                        0.005599  ...
#
#                question_type_choice  question_type_compare  \
# category
# CULTURE                    0.362063               0.064728
# LIFE_ARTS                  0.346732               0.062529
# SCIENCE                    0.287284               0.050958
# STACKOVERFLOW              0.180101               0.011838
# TECHNOLOGY                 0.289635               0.030315
#
#                question_type_consequence  question_type_definition  \
# category
# CULTURE                         0.015922                  0.122880
# LIFE_ARTS                       0.023037                  0.018336
# SCIENCE                         0.013558                  0.044881
# STACKOVERFLOW                   0.003857                  0.004123
# TECHNOLOGY                      0.006077                  0.007579
#
#                question_type_entity  question_type_instructions  \
# category
# CULTURE                    0.102285                    0.171859
# LIFE_ARTS                  0.111189                    0.283733
# SCIENCE                    0.090930                    0.305984
# STACKOVERFLOW              0.019420                    0.751264
# TECHNOLOGY                 0.053257                    0.613956
#
#                question_type_procedure  question_type_reason_explanation  \
# category
# CULTURE                       0.106784                          0.453617
# LIFE_ARTS                     0.125294                          0.459567
# SCIENCE                       0.147499                          0.557270
# STACKOVERFLOW                 0.202447                          0.301676
# TECHNOLOGY                    0.188038                          0.332173
#
#                question_type_spelling  question_well_written
# category
# CULTURE                      0.005192               0.857390
# LIFE_ARTS                    0.000000               0.883325
# SCIENCE                      0.000000               0.791258
# STACKOVERFLOW                0.000000               0.733573
# TECHNOLOGY                   0.000000               0.789635
#
# [5 rows x 21 columns]

# %%
# target_arr=np.array(targets)

# %% [markdown]
# ## Modeling

# %%
def get_score(base_prediction):
    overall_score = 0
    for col in targets:
        overall_score += spearmanr(base_prediction[col], train[col]).correlation/len(targets)
#         print(col, spearmanr(base_prediction[col], train[col]).correlation)
    return overall_score

# %%
category_mean_map = train.groupby("category")[targets].mean().T.to_dict()
base_prediction = train["category"].map(category_mean_map).apply(pd.Series)
get_score(base_prediction)
# Out:
# 0.1778908169176626

# %%
#Interaction term for Category and Host
train["category_host"]=train["category"]+train["host"]
category_mean_map = train.groupby(["category_host"])[targets].mean().T.to_dict()
categorical_prediction = train["category_host"].map(category_mean_map).apply(pd.Series)
get_score(categorical_prediction)
# Out:
# 0.26741183151253567

# %%
categ={'LIFE_ARTS':1, 'CULTURE':2, 'SCIENCE':3, 'STACKOVERFLOW':4, 'TECHNOLOGY':5}

train["category_num"]=train["category"].map(categ)

# %%
train["ans_length"]=train["answer"].apply(len)
# train["ans_length"]=train["ans_length"]/train["ans_length"].mean()
train["ans_length"]
# Out:
# 0        833
# 1        451
# 2       1048
# 3       1337
# 4        225
#         ...
# 6074    1309
# 6075    1122
# 6076     134
# 6077    1429
# 6078    1129
# Name: ans_length, Length: 6079, dtype: int64

# %%
train["length_user_name"]=train["question_user_name"].apply(len)

# %% [markdown]
# ### Sentiment Analysis

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyser = SentimentIntensityAnalyzer()

def sentiment_analyzer_score(answer):
    score=[]
    for sentence in answer:
        score.append(analyser.polarity_scores(sentence)['compound'])
    return np.array(score).mean()

# %%
train["clean_answer"]=train["answer"].apply(lambda x: [x for x in x.split("\n") if x!=''])

train["ans_sentiment"]=train["clean_answer"].apply(sentiment_analyzer_score)

# %%
train["ans_sentiment"]
# Out:
# 0      -0.173071
# 1      -0.363800
# 2       0.260740
# 3      -0.000423
# 4       0.060200
#           ...
# 6074    0.370033
# 6075   -0.153300
# 6076   -0.109100
# 6077    0.072471
# 6078    0.241175
# Name: ans_sentiment, Length: 6079, dtype: float64

# %%
train.columns
# Out:
# Index(['qa_id', 'question_title', 'question_body', 'question_user_name',
#        'question_user_page', 'answer', 'answer_user_name', 'answer_user_page',
#        'url', 'category', 'host', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written', 'answer_helpful',
#        'answer_level_of_information', 'answer_plausible', 'answer_relevance',
#        'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written', 'category_host', 'category_num', 'ans_length',
#        'length_user_name', 'clean_answer', 'ans_sentiment'],
#       dtype='object')

# %%
tfidf = TfidfVectorizer(ngram_range=(1, 3))
tsvd = TruncatedSVD(n_components = 50)

# %%
question_title = tfidf.fit_transform(train["question_title"].values)
question_title_test = tfidf.transform(test["question_title"].values)
question_title = tsvd.fit_transform(question_title)
question_title_test = tsvd.transform(question_title_test)

question_body = tfidf.fit_transform(train["question_body"].values)
question_body_test = tfidf.transform(test["question_body"].values)
question_body = tsvd.fit_transform(question_body)
question_body_test = tsvd.transform(question_body_test)

answer = tfidf.fit_transform(train["answer"].values)
answer_test = tfidf.transform(test["answer"].values)
answer = tsvd.fit_transform(answer)
answer_test = tsvd.transform(answer_test)

question_user_name = train["length_user_name"].values
category = train["category_num"].values
ans_length = train["ans_length"].values
ans_sentiment = train["ans_sentiment"].values

category_mean_map = train.groupby(["category_host"])[targets].mean().T.to_dict()
categorical_prediction = train["category_host"].map(category_mean_map).apply(pd.Series)


test["ans_length"]=test["answer"].apply(len)
test["ans_length"]
test["category_num"]=test["category"].map(categ)
test["clean_answer"]=test["answer"].apply(lambda x: [x for x in x.split("\n") if x!=''])
test["ans_sentiment"]=test["clean_answer"].apply(sentiment_analyzer_score)
test["length_user_name"]=test["question_user_name"].apply(len)



question_user_name_test = test["length_user_name"].values
category_test = test["category_num"].values
ans_length_test = test["ans_length"].values
ans_sentiment_test = test["ans_sentiment"].values

# %%
train_features = np.concatenate([question_title, question_body, answer,
                                 category[:, np.newaxis],ans_sentiment[:, np.newaxis],
                                 question_user_name[:, np.newaxis] #, category_te.values
                                ], axis = 1)


test_features = np.concatenate([question_title_test, question_body_test, answer_test,
                                category_test[:, np.newaxis],ans_sentiment_test[:, np.newaxis],
                                question_user_name_test[:, np.newaxis] #, category_te_test.values
                               ], axis = 1)

# %%
train_qfeatures = np.concatenate([question_title, question_body, 
                                 category[:, np.newaxis],
                                 question_user_name[:, np.newaxis]
                                ], axis = 1)

train_afeatures = np.concatenate([answer,
                                 category[:, np.newaxis],ans_sentiment[:, np.newaxis]], axis = 1)


test_qfeatures = np.concatenate([question_title_test, question_body_test,
                                category_test[:, np.newaxis],
                                question_user_name_test[:, np.newaxis]
                               ], axis = 1)

test_afeatures = np.concatenate([answer_test,
                                category_test[:, np.newaxis],ans_sentiment_test[:, np.newaxis]], axis = 1)

# %% [markdown]
# # NN

# %%
def create_model(train_features,train_y):
    inps = Input(shape=(train_features.shape[1],))
    x = Dense(256, activation='elu')(inps)
    x = Dropout(0.2)(x)
#     x = Dense(64)(x)
    x = Dense(train_y.shape[1], activation='sigmoid')(x)
    model = Model(inputs=inps, outputs=x)
    model.compile(
        optimizer=Adam(lr=1e-4),
        loss=['binary_crossentropy']
    )
    model.summary()
    return model

# %%
num_folds = 5
fold_scores = []
kf = KFold(n_splits = num_folds, shuffle = True, random_state = 42)
test_preds = np.zeros((len(test_features), len(targets)))

for ind, (train_index, val_index) in enumerate(kf.split(train_features)):
    train_X = train_features[train_index, :]
    train_y = train[targets].iloc[train_index]
    
    val_X = train_features[val_index, :]
    val_y = train[targets].iloc[val_index]
    
    model=create_model(train_features,train_y)

    es = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='auto')
    
    model.compile(optimizer='adam', loss='binary_crossentropy')
    
    model.fit(train_X, train_y, epochs = 50, validation_data=(val_X, val_y), callbacks = [es])
    preds = model.predict(val_X)
    overall_score = 0
    for col_index, col in enumerate(targets):
        overall_score += spearmanr(preds[:, col_index], val_y[col].values).correlation/len(targets)
        print(col, spearmanr(preds[:, col_index], val_y[col].values).correlation)
    fold_scores.append(overall_score)

test_preds += model.predict(test_features)/num_folds
    
print(np.mean(fold_scores))
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 153)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               39424
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 30)                7710
# =================================================================
# Total params: 47,134
# Trainable params: 47,134
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# 4863/4863 [==============================] - 1s 178us/step - loss: 0.4498 - val_loss: 0.4217
# Epoch 2/50
# 4863/4863 [==============================] - 0s 61us/step - loss: 0.4217 - val_loss: 0.4114
# Epoch 3/50
# 4863/4863 [==============================] - 0s 56us/step - loss: 0.4102 - val_loss: 0.4043
# Epoch 4/50
# 4863/4863 [==============================] - 0s 64us/step - loss: 0.4030 - val_loss: 0.3989
# Epoch 5/50
# 4863/4863 [==============================] - 0s 69us/step - loss: 0.3979 - val_loss: 0.3951
# Epoch 6/50
# 4863/4863 [==============================] - 0s 58us/step - loss: 0.3942 - val_loss: 0.3935
# Epoch 7/50
# 4863/4863 [==============================] - 0s 62us/step - loss: 0.3918 - val_loss: 0.3921
# Epoch 8/50
# 4863/4863 [==============================] - 0s 75us/step - loss: 0.3899 - val_loss: 0.3903
# Epoch 9/50
# 4863/4863 [==============================] - 0s 72us/step - loss: 0.3887 - val_loss: 0.3899
# Epoch 10/50
# 4863/4863 [==============================] - 0s 61us/step - loss: 0.3878 - val_loss: 0.3903
# Epoch 11/50
# 4863/4863 [==============================] - 0s 61us/step - loss: 0.3865 - val_loss: 0.3891
# Epoch 12/50
# 4863/4863 [==============================] - 0s 81us/step - loss: 0.3858 - val_loss: 0.3893
# Epoch 13/50
# 4863/4863 [==============================] - 0s 71us/step - loss: 0.3852 - val_loss: 0.3884
# Epoch 14/50
# 4863/4863 [==============================] - 0s 55us/step - loss: 0.3852 - val_loss: 0.3884
# Epoch 15/50
# 4863/4863 [==============================] - 0s 78us/step - loss: 0.3842 - val_loss: 0.3880
# Epoch 16/50
# 4863/4863 [==============================] - 0s 56us/step - loss: 0.3838 - val_loss: 0.3882
# Epoch 17/50
# 4863/4863 [==============================] - 0s 70us/step - loss: 0.3840 - val_loss: 0.3873
# Epoch 18/50
# 4863/4863 [==============================] - 0s 73us/step - loss: 0.3832 - val_loss: 0.3878
# Epoch 19/50
# 4863/4863 [==============================] - 0s 69us/step - loss: 0.3828 - val_loss: 0.3879
# Epoch 20/50
# 4863/4863 [==============================] - 0s 66us/step - loss: 0.3829 - val_loss: 0.3873
# Epoch 21/50
# 4863/4863 [==============================] - 0s 75us/step - loss: 0.3825 - val_loss: 0.3872
# Epoch 22/50
# 4863/4863 [==============================] - 0s 68us/step - loss: 0.3822 - val_loss: 0.3880
# Epoch 23/50
# 4863/4863 [==============================] - 0s 71us/step - loss: 0.3821 - val_loss: 0.3870
# Epoch 24/50
# 4863/4863 [==============================] - 0s 69us/step - loss: 0.3821 - val_loss: 0.3879
# Epoch 25/50
# 4863/4863 [==============================] - 0s 70us/step - loss: 0.3817 - val_loss: 0.3876
# Epoch 26/50
# 4863/4863 [==============================] - 0s 76us/step - loss: 0.3816 - val_loss: 0.3874
# Epoch 27/50
# 4863/4863 [==============================] - 0s 67us/step - loss: 0.3814 - val_loss: 0.3877
# Epoch 28/50
# 4863/4863 [==============================] - 0s 65us/step - loss: 0.3813 - val_loss: 0.3881
# Epoch 29/50
# 4863/4863 [==============================] - 0s 65us/step - loss: 0.3813 - val_loss: 0.3873
# Epoch 30/50
# 4863/4863 [==============================] - 0s 80us/step - loss: 0.3813 - val_loss: 0.3874
# Epoch 31/50
# 4863/4863 [==============================] - 0s 67us/step - loss: 0.3812 - val_loss: 0.3872
# Epoch 32/50
# 4863/4863 [==============================] - 0s 66us/step - loss: 0.3811 - val_loss: 0.3869
# Epoch 33/50
# 4863/4863 [==============================] - 0s 61us/step - loss: 0.3811 - val_loss: 0.3874
# Epoch 34/50
# 4863/4863 [==============================] - 0s 70us/step - loss: 0.3806 - val_loss: 0.3876
# Epoch 35/50
# 4863/4863 [==============================] - 0s 74us/step - loss: 0.3807 - val_loss: 0.3874
# Epoch 36/50
# 4863/4863 [==============================] - 0s 77us/step - loss: 0.3803 - val_loss: 0.3873
# Epoch 37/50
# 4863/4863 [==============================] - 0s 65us/step - loss: 0.3809 - val_loss: 0.3873
# Epoch 38/50
# 4863/4863 [==============================] - 0s 56us/step - loss: 0.3808 - val_loss: 0.3874
# Epoch 39/50
# 4863/4863 [==============================] - 0s 57us/step - loss: 0.3806 - val_loss: 0.3875
# Epoch 40/50
# 4863/4863 [==============================] - 0s 71us/step - loss: 0.3804 - val_loss: 0.3872
# Epoch 41/50
# 4863/4863 [==============================] - 0s 71us/step - loss: 0.3802 - val_loss: 0.3872
# Epoch 42/50
# 4863/4863 [==============================] - 0s 72us/step - loss: 0.3800 - val_loss: 0.3872
# answer_helpful 0.21827595052939155
# answer_level_of_information 0.3869814388858776
# answer_plausible 0.11481639739497736
# answer_relevance 0.13165683479804807
# answer_satisfaction 0.2879342171692944
# answer_type_instructions 0.6946382347763664
# answer_type_procedure 0.2506944095981037
# answer_type_reason_explanation 0.5539626998096868
# answer_well_written 0.14299999720713716
# question_asker_intent_understanding 0.3126783183936085
# question_body_critical 0.5374148338871174
# question_conversational 0.3638088969855322
# question_expect_short_answer 0.2282581067394563
# question_fact_seeking 0.21186574482395387
# question_has_commonly_accepted_answer 0.39389817448280606
# question_interestingness_others 0.32286131315098593
# question_interestingness_self 0.44167688343017664
# question_multi_intent 0.3340746549697127
# question_not_really_a_question 0.03661635189565712
# question_opinion_seeking 0.3476704394739561
# question_type_choice 0.5009401139825627
# question_type_compare 0.3082268069742484
# question_type_consequence 0.10058017449943424
# question_type_definition 0.31153817046176685
# question_type_entity 0.34738170332558616
# question_type_instructions 0.7034710365943609
# question_type_procedure 0.28581967150260235
# question_type_reason_explanation 0.5302195856975713
# question_type_spelling 0.043601707716538936
# question_well_written 0.4502548531838137
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 153)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               39424
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                7710
# =================================================================
# Total params: 47,134
# Trainable params: 47,134
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# 4863/4863 [==============================] - 1s 105us/step - loss: 0.4470 - val_loss: 0.4194
# Epoch 2/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.4201 - val_loss: 0.4094
# Epoch 3/50
# 4863/4863 [==============================] - 0s 68us/step - loss: 0.4095 - val_loss: 0.4025
# Epoch 4/50
# 4863/4863 [==============================] - 0s 64us/step - loss: 0.4024 - val_loss: 0.3980
# Epoch 5/50
# 4863/4863 [==============================] - 0s 63us/step - loss: 0.3974 - val_loss: 0.3950
# Epoch 6/50
# 4863/4863 [==============================] - 0s 55us/step - loss: 0.3941 - val_loss: 0.3930
# Epoch 7/50
# 4863/4863 [==============================] - 0s 63us/step - loss: 0.3916 - val_loss: 0.3912
# Epoch 8/50
# 4863/4863 [==============================] - 0s 78us/step - loss: 0.3894 - val_loss: 0.3908
# Epoch 9/50
# 4863/4863 [==============================] - 0s 55us/step - loss: 0.3886 - val_loss: 0.3905
# Epoch 10/50
# 4863/4863 [==============================] - 0s 55us/step - loss: 0.3877 - val_loss: 0.3889
# Epoch 11/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3868 - val_loss: 0.3895
# Epoch 12/50
# 4863/4863 [==============================] - 0s 53us/step - loss: 0.3860 - val_loss: 0.3887
# Epoch 13/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3853 - val_loss: 0.3896
# Epoch 14/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3849 - val_loss: 0.3886
# Epoch 15/50
# 4863/4863 [==============================] - 0s 53us/step - loss: 0.3842 - val_loss: 0.3888
# Epoch 16/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3842 - val_loss: 0.3881
# Epoch 17/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3838 - val_loss: 0.3878
# Epoch 18/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3833 - val_loss: 0.3876
# Epoch 19/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3829 - val_loss: 0.3875
# Epoch 20/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3830 - val_loss: 0.3877
# Epoch 21/50
# 4863/4863 [==============================] - 0s 56us/step - loss: 0.3828 - val_loss: 0.3883
# Epoch 22/50
# 4863/4863 [==============================] - 0s 68us/step - loss: 0.3824 - val_loss: 0.3874
# Epoch 23/50
# 4863/4863 [==============================] - 0s 61us/step - loss: 0.3823 - val_loss: 0.3873
# Epoch 24/50
# 4863/4863 [==============================] - 0s 58us/step - loss: 0.3823 - val_loss: 0.3876
# Epoch 25/50
# 4863/4863 [==============================] - 0s 57us/step - loss: 0.3821 - val_loss: 0.3876
# Epoch 26/50
# 4863/4863 [==============================] - 0s 63us/step - loss: 0.3820 - val_loss: 0.3871
# Epoch 27/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3818 - val_loss: 0.3868
# Epoch 28/50
# 4863/4863 [==============================] - 0s 57us/step - loss: 0.3815 - val_loss: 0.3869
# Epoch 29/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3815 - val_loss: 0.3881
# Epoch 30/50
# 4863/4863 [==============================] - 0s 55us/step - loss: 0.3817 - val_loss: 0.3867
# Epoch 31/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3812 - val_loss: 0.3873
# Epoch 32/50
# 4863/4863 [==============================] - ETA: 0s - loss: 0.381 - 0s 52us/step - loss: 0.3812 - val_loss: 0.3874
# Epoch 33/50
# 4863/4863 [==============================] - 0s 53us/step - loss: 0.3811 - val_loss: 0.3868
# Epoch 34/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3812 - val_loss: 0.3870
# Epoch 35/50
# 4863/4863 [==============================] - 0s 75us/step - loss: 0.3810 - val_loss: 0.3873
# Epoch 36/50
# 4863/4863 [==============================] - 0s 83us/step - loss: 0.3809 - val_loss: 0.3877
# Epoch 37/50
# 4863/4863 [==============================] - 0s 102us/step - loss: 0.3808 - val_loss: 0.3868
# Epoch 38/50
# 4863/4863 [==============================] - 0s 92us/step - loss: 0.3808 - val_loss: 0.3867
# Epoch 39/50
# 4863/4863 [==============================] - 0s 61us/step - loss: 0.3813 - val_loss: 0.3871
# Epoch 40/50
# 4863/4863 [==============================] - 0s 78us/step - loss: 0.3808 - val_loss: 0.3868
# answer_helpful 0.20619876272396562
# answer_level_of_information 0.3475850811460139
# answer_plausible 0.11763523922411398
# answer_relevance 0.12400390626869866
# answer_satisfaction 0.25635593776244114
# answer_type_instructions 0.6951784208311633
# answer_type_procedure 0.2308175892961268
# answer_type_reason_explanation 0.595120039655785
# answer_well_written 0.1502139948966528
# question_asker_intent_understanding 0.28312090731159534
# question_body_critical 0.5767518916868972
# question_conversational 0.36922132882743386
# question_expect_short_answer 0.1731093640700502
# question_fact_seeking 0.2489723169172982
# question_has_commonly_accepted_answer 0.3610906160953685
# question_interestingness_others 0.3193703957207404
# question_interestingness_self 0.420993384396488
# question_multi_intent 0.3286135216260094
# question_not_really_a_question 0.10077995285013643
# question_opinion_seeking 0.30525887131114304
# question_type_choice 0.47382819121133046
# question_type_compare 0.26854822742698026
# question_type_consequence 0.16367674706798482
# question_type_definition 0.32792607518831135
# question_type_entity 0.3423445083727757
# question_type_instructions 0.7010986659455024
# question_type_procedure 0.29189783999622315
# question_type_reason_explanation 0.503754204859478
# question_type_spelling 0.06408679677511799
# question_well_written 0.4803298599190654
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 153)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               39424
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 30)                7710
# =================================================================
# Total params: 47,134
# Trainable params: 47,134
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# 4863/4863 [==============================] - 1s 150us/step - loss: 0.4537 - val_loss: 0.4209
# Epoch 2/50
# 4863/4863 [==============================] - 0s 72us/step - loss: 0.4223 - val_loss: 0.4109
# Epoch 3/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.4103 - val_loss: 0.4036
# Epoch 4/50
# 4863/4863 [==============================] - 0s 56us/step - loss: 0.4029 - val_loss: 0.3992
# Epoch 5/50
# 4863/4863 [==============================] - 0s 49us/step - loss: 0.3976 - val_loss: 0.3964
# Epoch 6/50
# 4863/4863 [==============================] - 0s 49us/step - loss: 0.3944 - val_loss: 0.3939
# Epoch 7/50
# 4863/4863 [==============================] - 0s 49us/step - loss: 0.3917 - val_loss: 0.3926
# Epoch 8/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3900 - val_loss: 0.3910
# Epoch 9/50
# 4863/4863 [==============================] - 0s 60us/step - loss: 0.3888 - val_loss: 0.3913
# Epoch 10/50
# 4863/4863 [==============================] - 0s 81us/step - loss: 0.3877 - val_loss: 0.3901
# Epoch 11/50
# 4863/4863 [==============================] - 0s 70us/step - loss: 0.3867 - val_loss: 0.3894
# Epoch 12/50
# 4863/4863 [==============================] - 0s 62us/step - loss: 0.3860 - val_loss: 0.3913
# Epoch 13/50
# 4863/4863 [==============================] - 0s 55us/step - loss: 0.3854 - val_loss: 0.3895
# Epoch 14/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3850 - val_loss: 0.3889
# Epoch 15/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3842 - val_loss: 0.3884
# Epoch 16/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3840 - val_loss: 0.3892
# Epoch 17/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3835 - val_loss: 0.3888
# Epoch 18/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3833 - val_loss: 0.3880
# Epoch 19/50
# 4863/4863 [==============================] - 0s 53us/step - loss: 0.3829 - val_loss: 0.3878
# Epoch 20/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3826 - val_loss: 0.3884
# Epoch 21/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3825 - val_loss: 0.3878
# Epoch 22/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3825 - val_loss: 0.3887
# Epoch 23/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3821 - val_loss: 0.3878
# Epoch 24/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3818 - val_loss: 0.3878
# Epoch 25/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3818 - val_loss: 0.3878
# Epoch 26/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3816 - val_loss: 0.3875
# Epoch 27/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3812 - val_loss: 0.3876
# Epoch 28/50
# 4863/4863 [==============================] - 0s 50us/step - loss: 0.3814 - val_loss: 0.3881
# Epoch 29/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3813 - val_loss: 0.3873
# Epoch 30/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3814 - val_loss: 0.3881
# Epoch 31/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3809 - val_loss: 0.3876
# Epoch 32/50
# 4863/4863 [==============================] - 0s 50us/step - loss: 0.3808 - val_loss: 0.3891
# Epoch 33/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3810 - val_loss: 0.3890
# Epoch 34/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3807 - val_loss: 0.3879
# Epoch 35/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3805 - val_loss: 0.3879
# Epoch 36/50
# 4863/4863 [==============================] - 0s 51us/step - loss: 0.3808 - val_loss: 0.3880
# Epoch 37/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3804 - val_loss: 0.3879
# Epoch 38/50
# 4863/4863 [==============================] - 0s 57us/step - loss: 0.3803 - val_loss: 0.3882
# Epoch 39/50
# 4863/4863 [==============================] - 0s 57us/step - loss: 0.3807 - val_loss: 0.3884
# answer_helpful 0.1515913222663309
# answer_level_of_information 0.3301412398064884
# answer_plausible 0.12176456677752051
# answer_relevance 0.09149596518832279
# answer_satisfaction 0.21073073244781765
# answer_type_instructions 0.6977240590433974
# answer_type_procedure 0.23284684640990166
# answer_type_reason_explanation 0.5501963759509396
# answer_well_written 0.12634642718081265
# question_asker_intent_understanding 0.34503839030458744
# question_body_critical 0.5326409595768972
# question_conversational 0.37243563933370266
# question_expect_short_answer 0.15436294311889096
# question_fact_seeking 0.25757725261719877
# question_has_commonly_accepted_answer 0.39421306776864584
# question_interestingness_others 0.341164468090427
# question_interestingness_self 0.4635944070567194
# question_multi_intent 0.3409378647117678
# question_not_really_a_question 0.07582858081590768
# question_opinion_seeking 0.3541922758688593
# question_type_choice 0.4777375186946896
# question_type_compare 0.30157706703555925
# question_type_consequence 0.13577253422848984
# question_type_definition 0.33080217579802423
# question_type_entity 0.34406110465305434
# question_type_instructions 0.7092185368766135
# question_type_procedure 0.3063401055579161
# question_type_reason_explanation 0.49050520472678516
# question_type_spelling 0.08975941962070685
# question_well_written 0.45306320622147944
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 153)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               39424
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 30)                7710
# =================================================================
# Total params: 47,134
# Trainable params: 47,134
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4863 samples, validate on 1216 samples
# Epoch 1/50
# 4863/4863 [==============================] - 1s 107us/step - loss: 0.4484 - val_loss: 0.4200
# Epoch 2/50
# 4863/4863 [==============================] - 0s 66us/step - loss: 0.4210 - val_loss: 0.4100
# Epoch 3/50
# 4863/4863 [==============================] - 0s 67us/step - loss: 0.4102 - val_loss: 0.4024
# Epoch 4/50
# 4863/4863 [==============================] - 0s 65us/step - loss: 0.4029 - val_loss: 0.3972
# Epoch 5/50
# 4863/4863 [==============================] - 0s 68us/step - loss: 0.3979 - val_loss: 0.3945
# Epoch 6/50
# 4863/4863 [==============================] - 0s 66us/step - loss: 0.3946 - val_loss: 0.3942
# Epoch 7/50
# 4863/4863 [==============================] - 0s 70us/step - loss: 0.3928 - val_loss: 0.3906
# Epoch 8/50
# 4863/4863 [==============================] - 0s 73us/step - loss: 0.3907 - val_loss: 0.3887
# Epoch 9/50
# 4863/4863 [==============================] - 0s 70us/step - loss: 0.3891 - val_loss: 0.3889
# Epoch 10/50
# 4863/4863 [==============================] - 0s 79us/step - loss: 0.3879 - val_loss: 0.3875
# Epoch 11/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3875 - val_loss: 0.3872
# Epoch 12/50
# 4863/4863 [==============================] - 0s 80us/step - loss: 0.3868 - val_loss: 0.3870
# Epoch 13/50
# 4863/4863 [==============================] - 0s 66us/step - loss: 0.3861 - val_loss: 0.3869
# Epoch 14/50
# 4863/4863 [==============================] - 0s 63us/step - loss: 0.3857 - val_loss: 0.3871
# Epoch 15/50
# 4863/4863 [==============================] - 0s 64us/step - loss: 0.3854 - val_loss: 0.3858
# Epoch 16/50
# 4863/4863 [==============================] - 0s 71us/step - loss: 0.3846 - val_loss: 0.3858
# Epoch 17/50
# 4863/4863 [==============================] - 0s 68us/step - loss: 0.3847 - val_loss: 0.3857
# Epoch 18/50
# 4863/4863 [==============================] - 0s 64us/step - loss: 0.3839 - val_loss: 0.3866
# Epoch 19/50
# 4863/4863 [==============================] - 0s 60us/step - loss: 0.3834 - val_loss: 0.3866
# Epoch 20/50
# 4863/4863 [==============================] - 0s 70us/step - loss: 0.3833 - val_loss: 0.3860
# Epoch 21/50
# 4863/4863 [==============================] - 0s 72us/step - loss: 0.3834 - val_loss: 0.3855
# Epoch 22/50
# 4863/4863 [==============================] - 0s 74us/step - loss: 0.3833 - val_loss: 0.3863
# Epoch 23/50
# 4863/4863 [==============================] - 0s 72us/step - loss: 0.3829 - val_loss: 0.3851
# Epoch 24/50
# 4863/4863 [==============================] - 0s 63us/step - loss: 0.3829 - val_loss: 0.3854
# Epoch 25/50
# 4863/4863 [==============================] - 0s 63us/step - loss: 0.3826 - val_loss: 0.3849
# Epoch 26/50
# 4863/4863 [==============================] - 0s 56us/step - loss: 0.3825 - val_loss: 0.3864
# Epoch 27/50
# 4863/4863 [==============================] - 0s 66us/step - loss: 0.3823 - val_loss: 0.3852
# Epoch 28/50
# 4863/4863 [==============================] - 0s 73us/step - loss: 0.3823 - val_loss: 0.3878
# Epoch 29/50
# 4863/4863 [==============================] - 0s 61us/step - loss: 0.3819 - val_loss: 0.3851
# Epoch 30/50
# 4863/4863 [==============================] - 0s 58us/step - loss: 0.3820 - val_loss: 0.3856
# Epoch 31/50
# 4863/4863 [==============================] - 0s 57us/step - loss: 0.3816 - val_loss: 0.3853
# Epoch 32/50
# 4863/4863 [==============================] - 0s 65us/step - loss: 0.3816 - val_loss: 0.3846
# Epoch 33/50
# 4863/4863 [==============================] - 0s 76us/step - loss: 0.3814 - val_loss: 0.3853
# Epoch 34/50
# 4863/4863 [==============================] - 0s 65us/step - loss: 0.3816 - val_loss: 0.3847
# Epoch 35/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3814 - val_loss: 0.3846
# Epoch 36/50
# 4863/4863 [==============================] - 0s 59us/step - loss: 0.3812 - val_loss: 0.3851
# Epoch 37/50
# 4863/4863 [==============================] - 0s 61us/step - loss: 0.3813 - val_loss: 0.3851
# Epoch 38/50
# 4863/4863 [==============================] - 0s 58us/step - loss: 0.3815 - val_loss: 0.3860
# Epoch 39/50
# 4863/4863 [==============================] - 0s 57us/step - loss: 0.3813 - val_loss: 0.3848
# Epoch 40/50
# 4863/4863 [==============================] - 0s 74us/step - loss: 0.3810 - val_loss: 0.3847
# Epoch 41/50
# 4863/4863 [==============================] - 0s 57us/step - loss: 0.3812 - val_loss: 0.3852
# Epoch 42/50
# 4863/4863 [==============================] - 0s 57us/step - loss: 0.3811 - val_loss: 0.3855
# Epoch 43/50
# 4863/4863 [==============================] - 0s 53us/step - loss: 0.3808 - val_loss: 0.3846
# Epoch 44/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3808 - val_loss: 0.3850
# Epoch 45/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3809 - val_loss: 0.3852
# Epoch 46/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3808 - val_loss: 0.3849
# Epoch 47/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3808 - val_loss: 0.3848
# Epoch 48/50
# 4863/4863 [==============================] - 0s 52us/step - loss: 0.3809 - val_loss: 0.3856
# Epoch 49/50
# 4863/4863 [==============================] - 0s 54us/step - loss: 0.3806 - val_loss: 0.3849
# Epoch 50/50
# 4863/4863 [==============================] - 0s 53us/step - loss: 0.3808 - val_loss: 0.3850
# answer_helpful 0.15192290963772323
# answer_level_of_information 0.3387352978451875
# answer_plausible 0.12460528988000037
# answer_relevance 0.10331460810218489
# answer_satisfaction 0.2117346849400973
# answer_type_instructions 0.7078195590435464
# answer_type_procedure 0.23776583078850294
# answer_type_reason_explanation 0.562866946209229
# answer_well_written 0.0975090823063265
# question_asker_intent_understanding 0.28715314315602314
# question_body_critical 0.5626356564212488
# question_conversational 0.39876500601399273
# question_expect_short_answer 0.21635925571761896
# question_fact_seeking 0.27275842437681713
# question_has_commonly_accepted_answer 0.3946138445804777
# question_interestingness_others 0.3673393698793026
# question_interestingness_self 0.46190370046197
# question_multi_intent 0.3630655351364141
# question_not_really_a_question 0.09132502963590863
# question_opinion_seeking 0.34093659370464313
# question_type_choice 0.4918359116484224
# question_type_compare 0.3093571019487159
# question_type_consequence 0.14666080788388802
# question_type_definition 0.38554975637923344
# question_type_entity 0.3252610489028089
# question_type_instructions 0.715252449363592
# question_type_procedure 0.26205782934000177
# question_type_reason_explanation 0.5375304841341777
# question_type_spelling 0.049486099633574636
# question_well_written 0.4520619574896188
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 153)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               39424
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 30)                7710
# =================================================================
# Total params: 47,134
# Trainable params: 47,134
# Non-trainable params: 0
# _________________________________________________________________
# Train on 4864 samples, validate on 1215 samples
# Epoch 1/50
# 4864/4864 [==============================] - 0s 84us/step - loss: 0.4526 - val_loss: 0.4196
# Epoch 2/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.4214 - val_loss: 0.4105
# Epoch 3/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.4109 - val_loss: 0.4033
# Epoch 4/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.4032 - val_loss: 0.3996
# Epoch 5/50
# 4864/4864 [==============================] - 0s 51us/step - loss: 0.3981 - val_loss: 0.3951
# Epoch 6/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3946 - val_loss: 0.3935
# Epoch 7/50
# 4864/4864 [==============================] - 0s 54us/step - loss: 0.3919 - val_loss: 0.3918
# Epoch 8/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3902 - val_loss: 0.3901
# Epoch 9/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3885 - val_loss: 0.3897
# Epoch 10/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3878 - val_loss: 0.3890
# Epoch 11/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3865 - val_loss: 0.3894
# Epoch 12/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3861 - val_loss: 0.3881
# Epoch 13/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3851 - val_loss: 0.3885
# Epoch 14/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3849 - val_loss: 0.3881
# Epoch 15/50
# 4864/4864 [==============================] - 0s 54us/step - loss: 0.3844 - val_loss: 0.3877
# Epoch 16/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3838 - val_loss: 0.3875
# Epoch 17/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3835 - val_loss: 0.3880
# Epoch 18/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3833 - val_loss: 0.3875
# Epoch 19/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3830 - val_loss: 0.3873
# Epoch 20/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3829 - val_loss: 0.3873
# Epoch 21/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3829 - val_loss: 0.3880
# Epoch 22/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3824 - val_loss: 0.3880
# Epoch 23/50
# 4864/4864 [==============================] - 0s 54us/step - loss: 0.3822 - val_loss: 0.3875
# Epoch 24/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3819 - val_loss: 0.3870
# Epoch 25/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3822 - val_loss: 0.3872
# Epoch 26/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3816 - val_loss: 0.3871
# Epoch 27/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3818 - val_loss: 0.3870
# Epoch 28/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3815 - val_loss: 0.3877
# Epoch 29/50
# 4864/4864 [==============================] - 0s 58us/step - loss: 0.3815 - val_loss: 0.3874
# Epoch 30/50
# 4864/4864 [==============================] - 0s 62us/step - loss: 0.3815 - val_loss: 0.3872
# Epoch 31/50
# 4864/4864 [==============================] - 0s 69us/step - loss: 0.3812 - val_loss: 0.3876
# Epoch 32/50
# 4864/4864 [==============================] - 0s 54us/step - loss: 0.3812 - val_loss: 0.3870
# Epoch 33/50
# 4864/4864 [==============================] - 0s 59us/step - loss: 0.3810 - val_loss: 0.3871
# Epoch 34/50
# 4864/4864 [==============================] - 0s 56us/step - loss: 0.3809 - val_loss: 0.3875
# Epoch 35/50
# 4864/4864 [==============================] - 0s 80us/step - loss: 0.3807 - val_loss: 0.3870
# Epoch 36/50
# 4864/4864 [==============================] - 0s 54us/step - loss: 0.3805 - val_loss: 0.3868
# Epoch 37/50
# 4864/4864 [==============================] - 0s 62us/step - loss: 0.3806 - val_loss: 0.3888
# Epoch 38/50
# 4864/4864 [==============================] - 0s 56us/step - loss: 0.3805 - val_loss: 0.3875
# Epoch 39/50
# 4864/4864 [==============================] - 0s 56us/step - loss: 0.3804 - val_loss: 0.3879
# Epoch 40/50
# 4864/4864 [==============================] - 0s 54us/step - loss: 0.3804 - val_loss: 0.3873
# Epoch 41/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3804 - val_loss: 0.3872
# Epoch 42/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3803 - val_loss: 0.3871
# Epoch 43/50
# 4864/4864 [==============================] - 0s 54us/step - loss: 0.3801 - val_loss: 0.3875
# Epoch 44/50
# 4864/4864 [==============================] - 0s 60us/step - loss: 0.3802 - val_loss: 0.3869
# Epoch 45/50
# 4864/4864 [==============================] - 0s 52us/step - loss: 0.3802 - val_loss: 0.3874
# Epoch 46/50
# 4864/4864 [==============================] - 0s 53us/step - loss: 0.3801 - val_loss: 0.3875
# answer_helpful 0.15210691966658485
# answer_level_of_information 0.38857308494705917
# answer_plausible 0.12910416912986283
# answer_relevance 0.1523024854863363
# answer_satisfaction 0.22457916608350492
# answer_type_instructions 0.697437733814834
# answer_type_procedure 0.22507425834427286
# answer_type_reason_explanation 0.5712574242223211
# answer_well_written 0.13473099091800295
# question_asker_intent_understanding 0.3110919472285479
# question_body_critical 0.5567094239331145
# question_conversational 0.34197893521213785
# question_expect_short_answer 0.1909040629606491
# question_fact_seeking 0.21011914601630208
# question_has_commonly_accepted_answer 0.3199520732821639
# question_interestingness_others 0.31881276370139716
# question_interestingness_self 0.42998168030042344
# question_multi_intent 0.341055273720645
# question_not_really_a_question 0.06534072765846506
# question_opinion_seeking 0.33079185529965305
# question_type_choice 0.4584017797439985
# question_type_compare 0.24304337275762758
# question_type_consequence 0.15014796160600077
# question_type_definition 0.3174502867364558
# question_type_entity 0.35914639399029114
# question_type_instructions 0.7068343618772391
# question_type_procedure 0.2700767541551474
# question_type_reason_explanation 0.5102254903969374
# question_type_spelling 0.07058754855489156
# question_well_written 0.4451909249004981
# 0.32731701887117526

# %%
print(np.mean([0.3195548000990476, 0.3262502129023895, 0.3223079742789521, 0.32946711725179056, 0.3161551600057016]))
print(np.mean([0.32479519515893235, 0.3239592931685162, 0.32134253797573153, 0.328557157181304, 0.31646135779054296]))
print(np.mean([0.3245549329463598, 0.32751179135116537, 0.32642514407411216, 0.32738338815754314, 0.32139129196247973]))

print(0.3255922799258237)
# Out:
# 0.32274705290757627
# 0.32302310825500535
# 0.325453309698332
# 0.3255922799258237

# %%
targets[29]
# Out:
# 'question_well_written'

# %% [markdown]
# ## Analysis

# %%
round(train_features.shape[0]*0.7)
# Out:
# 4255

# %%
targets
# Out:
# Index(['answer_helpful', 'answer_level_of_information', 'answer_plausible',
#        'answer_relevance', 'answer_satisfaction', 'answer_type_instructions',
#        'answer_type_procedure', 'answer_type_reason_explanation',
#        'answer_well_written', 'question_asker_intent_understanding',
#        'question_body_critical', 'question_conversational',
#        'question_expect_short_answer', 'question_fact_seeking',
#        'question_has_commonly_accepted_answer',
#        'question_interestingness_others', 'question_interestingness_self',
#        'question_multi_intent', 'question_not_really_a_question',
#        'question_opinion_seeking', 'question_type_choice',
#        'question_type_compare', 'question_type_consequence',
#        'question_type_definition', 'question_type_entity',
#        'question_type_instructions', 'question_type_procedure',
#        'question_type_reason_explanation', 'question_type_spelling',
#        'question_well_written'],
#       dtype='object')

# %%
pred=[None]*30
test_pred=[None]*30
for i in range(len(targets)):
    
    one_target=train[targets[i]]
    
#     train_X, val_X, train_y, val_y = train_test_split(train_features,one_target, test_size=0.2, random_state=777)
    if i < 9 :
        train_X=train_afeatures
        test_X=test_afeatures
    else:
        train_X=train_qfeatures
        test_X=test_qfeatures

    mod1=LinearRegression()
    mod2=AdaBoostRegressor()
    mod3=XGBRegressor(objective='reg:squarederror')

#     mod3.fit(train_X,train_y)
    mod3.fit(train_X,one_target)

#     pred[i]=mod3.predict(val_X)
    test_pred[i]=mod3.predict(test_X)
    
    
#     overall_score += spearmanr(pred[i], val_y.values).correlation
#     print(i, spearmanr(pred[i], val_y.values).correlation) 



# print("\n\n\nOverall: ")
# print(overall_score/len(targets))
# Out:
# /Users/subhayuchakravarty/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /Users/subhayuchakravarty/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
# VALIDATION

overall_score = 0
spearman=[]
pred=[None]*30
test_pred=[None]*30

train_X, val_X, train_y, val_y = train_test_split(train_features,train[targets], test_size=0.2, random_state=777)

for i in range(len(targets)):
    
    train_one_y=train_y.iloc[:,i]

    mod1=LinearRegression()
    mod2=AdaBoostRegressor()
    mod3=XGBRegressor(objective='reg:squarederror')

    mod3.fit(train_X,train_one_y)
    pred[i]=mod3.predict(val_X)
    print("Predicted: "+str(i))

p=np.array(pred)
p=p.T
overall_score = 0
for col_index, col in enumerate(targets):
    overall_score += spearmanr(p[:, col_index], val_y[col].values).correlation/len(targets)
    print(col, spearmanr(p[:, col_index], val_y[col].values).correlation)

print("\n\n\nOverall: "+str(overall_score))
# Out:
# /Users/subhayuchakravarty/anaconda3/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \
# Predicted: 0
# Predicted: 1
# Predicted: 2
# Predicted: 3
# Predicted: 4
# Predicted: 5
# Predicted: 6
# Predicted: 7
# Predicted: 8
# Predicted: 9
# Predicted: 10
# Predicted: 11
# Predicted: 12
# Predicted: 13
# Predicted: 14
# Predicted: 15
# Predicted: 16
# Predicted: 17
# Predicted: 18
# Predicted: 19
# Predicted: 20
# Predicted: 21
# Predicted: 22
# Predicted: 23
# Predicted: 24
# Predicted: 25
# Predicted: 26
# Predicted: 27
# Predicted: 28
# Predicted: 29
# answer_helpful 0.19987282323094183
# answer_level_of_information 0.38250162301975105
# answer_plausible 0.12435106895643877
# answer_relevance 0.09909243524505924
# answer_satisfaction 0.24904307862627956
# answer_type_instructions 0.7269174453827595
# answer_type_procedure 0.2602891204325799
# answer_type_reason_explanation 0.5459137910283691
# answer_well_written 0.1280937093839501
# question_asker_intent_understanding 0.33484471013877465
# question_body_critical 0.6046669784792577
# question_conversational 0.34580817163475625
# question_expect_short_answer 0.23866417094461503
# question_fact_seeking 0.292025734352656
# question_has_commonly_accepted_answer 0.3784246336162355
# question_interestingness_others 0.32409887262691045
# question_interestingness_self 0.44744919399182087
# question_multi_intent 0.3722232339504348
# question_not_really_a_question 0.02047516616654131
# question_opinion_seeking 0.3779842662570145
# question_type_choice 0.5482533777122599
# question_type_compare 0.2695188614301239
# question_type_consequence 0.08027580392577618
# question_type_definition 0.3362278914728273
# question_type_entity 0.3242673790025892
# question_type_instructions 0.7433624432212677
# question_type_procedure 0.2976308394696403
# question_type_reason_explanation 0.5458929725148971
# question_type_spelling 0.06365319436818237
# question_well_written 0.4696719980613339
#
#
#
# Overall: 0.3377164996214681

# %%
# VALIDATION - Q,A separate

pred=[None]*30
overall_score = 0
for i in range(len(targets)):
    
    one_target=train[targets[i]]
    
    
    if i < 9 :
        train_X, val_X, train_y, val_y = train_test_split(train_afeatures,one_target, test_size=0.2, random_state=7)

    else:
        train_X, val_X, train_y, val_y = train_test_split(train_qfeatures,one_target, test_size=0.2, random_state=7)

    mod1=LinearRegression()
    mod2=AdaBoostRegressor()
    mod3=XGBRegressor(objective='reg:squarederror')

    mod3.fit(train_X,train_y)
    pred[i]=mod3.predict(val_X)

    
    
    overall_score += spearmanr(pred[i], val_y.values).correlation
    print(i, spearmanr(pred[i], val_y.values).correlation) 



print("\n\n\nOverall: ")
print(overall_score/len(targets))
# Out:
# 0 0.1561521111167548
# 1 0.3341777541328594
# 2 0.07233419163317333
# 3 0.051695491321165576
# 4 0.2074495761503917
# 5 0.6651229711310459
# 6 0.14441001358422148
# 7 0.49470492585924514
# 8 0.1583237939767057
# 9 0.3654409107137195
# 10 0.623696766104946
# 11 0.33463955127607786
# 12 0.2110026766999851
# 13 0.30546863476661523
# 14 0.3833162074331399
# 15 0.36795743365974914
# 16 0.47555064630080035
# 17 0.34838958535576253
# 18 0.07166879952809352
# 19 0.3621741946809549
# 20 0.5156170625294693
# 21 0.3220150278457807
# 22 0.10638302831361096
# 23 0.33277286962949226
# 24 0.3819310187285612
# 25 0.725764940419561
# 26 0.29109897485285835
# 27 0.5428693298571567
# 28 0.052552924697908225
# 29 0.50474162309165
#
#
#
# Overall:
# 0.33031410117971516

# %%
pred[0]
# Out:
# array([0.91753891, 0.95790617, 0.90934025, ..., 0.95223587, 0.92944667,
#        0.94502673])

# %%
question_title.shape
# Out:
# (6079, 50)

# %%
train[targets[0]]
# Out:
# 0       1.000000
# 1       0.888889
# 2       0.777778
# 3       0.833333
# 4       1.000000
#           ...
# 6074    1.000000
# 6075    0.888889
# 6076    0.888889
# 6077    0.888889
# 6078    0.888889
# Name: answer_helpful, Length: 6079, dtype: float64

# %%
test
# Out:
#      qa_id                                     question_title  \
# 0       39  Will leaving corpses lying around upset my pri...
# 1       46         Url link to feature image in the portfolio
# 2       70  Is accuracy, recoil or bullet spread affected ...
# 3      132     Suddenly got an I/O error from my external HDD
# 4      200  Passenger Name - Flight Booking Passenger only...
# ..     ...                                                ...
# 471   9569        change gb4e enumeration in only one chapter
# 472   9590                             All anagrams in a File
# 473   9597               SQL Server: Time Series Table Design
# 474   9623             Is a countered flashback spell exiled?
# 475   9640                               Find Friends In-Game
#
#                                          question_body question_user_name  \
# 0    I see questions/information online about how t...              Dylan
# 1    I am new to Wordpress. i have issue with Featu...                Anu
# 2    To experiment I started a bot game, toggled in...             Konsta
# 3    I have used my Raspberry Pi as a torrent-serve...           robbannn
# 4    I have bought Delhi-London return flights for ...               Amit
# ..                                                 ...                ...
# 471  I am using gb4e for glossing examples in my th...             ToddAO
# 472  Source : Microsoft Interview Question\n\nWe ar...            Spandan
# 473  I am creating a time series database that foll...        Jay Michael
# 474  If I flashback Past in Flames and it is counte...         BolasStone
# 475  Is there a way to mark friends you have queued...         Molten Ice
#
#                                     question_user_page  \
# 0         https://gaming.stackexchange.com/users/64471
# 1      https://wordpress.stackexchange.com/users/72927
# 2         https://gaming.stackexchange.com/users/37545
# 3    https://raspberrypi.stackexchange.com/users/17341
# 4         https://travel.stackexchange.com/users/29089
# ..                                                 ...
# 471          https://tex.stackexchange.com/users/28332
# 472            https://stackoverflow.com/users/2426101
# 473          https://dba.stackexchange.com/users/47001
# 474    https://boardgames.stackexchange.com/users/9981
# 475       https://gaming.stackexchange.com/users/54729
#
#                                                 answer answer_user_name  \
# 0    There is no consequence for leaving corpses an...        Nelson868
# 1    I think it is possible with custom fields.\n\n...            Irina
# 2    You do not have armour in the screenshots. Thi...   Damon Smithies
# 3    Your Western Digital hard drive is disappearin...      HeatfanJohn
# 4    I called two persons who work for Saudia (tick...    Nean Der Thal
# ..                                                 ...              ...
# 471  You can simply reset the exx counter just afte...      karlkoeller
# 472  Slightly different approach from the one above...    Algorithmatic
# 473  A foreign key can reference a unique constrain...        mustaccio
# 474  If you counter a spell cast for its Flashback ...     murgatroid99
# 475  Not officially, although you could both use cl...   Damon Smithies
#
#                                      answer_user_page  \
# 0        https://gaming.stackexchange.com/users/97324
# 1     https://wordpress.stackexchange.com/users/27233
# 2        https://gaming.stackexchange.com/users/70641
# 3    https://raspberrypi.stackexchange.com/users/1311
# 4        https://travel.stackexchange.com/users/10051
# ..                                                ...
# 471         https://tex.stackexchange.com/users/27635
# 472           https://stackoverflow.com/users/1122229
# 473         https://dba.stackexchange.com/users/23721
# 474   https://boardgames.stackexchange.com/users/2537
# 475      https://gaming.stackexchange.com/users/70641
#
#                                                    url       category  \
# 0    http://gaming.stackexchange.com/questions/1979...        CULTURE
# 1    http://wordpress.stackexchange.com/questions/1...     TECHNOLOGY
# 2    http://gaming.stackexchange.com/questions/2154...        CULTURE
# 3    http://raspberrypi.stackexchange.com/questions...     TECHNOLOGY
# 4    http://travel.stackexchange.com/questions/4704...        CULTURE
# ..                                                 ...            ...
# 471  http://tex.stackexchange.com/questions/165120/...     TECHNOLOGY
# 472  http://stackoverflow.com/questions/16872513/al...  STACKOVERFLOW
# 473  http://dba.stackexchange.com/questions/105287/...     TECHNOLOGY
# 474  http://boardgames.stackexchange.com/questions/...        CULTURE
# 475  http://gaming.stackexchange.com/questions/1582...        CULTURE
#
#                               host  ans_length  category_num  \
# 0         gaming.stackexchange.com         143             2
# 1      wordpress.stackexchange.com         317             5
# 2         gaming.stackexchange.com         112             2
# 3    raspberrypi.stackexchange.com        1514             5
# 4         travel.stackexchange.com         480             2
# ..                             ...         ...           ...
# 471          tex.stackexchange.com        1399             5
# 472              stackoverflow.com         611             4
# 473          dba.stackexchange.com         244             5
# 474   boardgames.stackexchange.com        1181             2
# 475       gaming.stackexchange.com         246             2
#
#                                           clean_answer  ans_sentiment  \
# 0    [There is no consequence for leaving corpses a...      -0.851100
# 1    [I think it is possible with custom fields., A...       0.217300
# 2    [You do not have armour in the screenshots. Th...      -0.153100
# 3    [Your Western Digital hard drive is disappeari...      -0.083443
# 4    [I called two persons who work for Saudia (tic...      -0.161050
# ..                                                 ...            ...
# 471  [You can simply reset the exx counter just aft...       0.000000
# 472  [Slightly different approach from the one abov...       0.000000
# 473  [A foreign key can reference a unique constrai...       0.144000
# 474  [If you counter a spell cast for its Flashback...       0.163825
# 475  [Not officially, although you could both use c...       0.000000
#
#      length_user_name
# 0                   5
# 1                   3
# 2                   6
# 3                   8
# 4                   4
# ..                ...
# 471                 6
# 472                 7
# 473                11
# 474                10
# 475                10
#
# [476 rows x 16 columns]

# %%
import bert

# %%
import gc
gc.collect()
# Out:
# 23753

# %%
t=np.array(test_pred)
t2=t.T
t2.shape
# Out:
# (476, 30)

# %%
submission = pd.DataFrame()
submission["qa_id"]=test["qa_id"]
for col_index, col in enumerate(targets):
    submission[col]=t2[:,col_index]

# %%
submission.to_csv("submission.csv", index = False)

# %%
submission.head()
# Out:
#    qa_id  answer_helpful  answer_level_of_information  answer_plausible  \
# 0     39        0.175706                     0.119767          0.189379
# 1     46        0.192659                     0.130590          0.195794
# 2     70        0.186076                     0.126293          0.194203
# 3    132        0.193241                     0.135362          0.197398
# 4    200        0.190922                     0.142368          0.195803
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0          0.191362             0.155808                  0.039329
# 1          0.197853             0.176641                  0.190104
# 2          0.194682             0.166624                  0.027667
# 3          0.197716             0.178573                  0.132498
# 4          0.197134             0.179300                  0.041263
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.013202                        0.158061             0.179542
# 1               0.025278                        0.046228             0.179280
# 2               0.021559                        0.146229             0.184762
# 3               0.033065                        0.153932             0.184942
# 4               0.018178                        0.162315             0.184523
#
#    ...  question_type_choice  question_type_compare  \
# 0  ...              0.090233               0.007123
# 1  ...              0.040379               0.000201
# 2  ...              0.113556               0.007974
# 3  ...              0.050236               0.003918
# 4  ...              0.067495               0.007330
#
#    question_type_consequence  question_type_definition  question_type_entity  \
# 0                   0.010739                  0.002000              0.013642
# 1                   0.000126                  0.000057              0.002122
# 2                   0.009348                  0.005527              0.005449
# 3                   0.002190                  0.000047              0.001597
# 4                   0.002994                  0.001523              0.006304
#
#    question_type_instructions  question_type_procedure  \
# 0                    0.035061                 0.026044
# 1                    0.190575                 0.038640
# 2                    0.027837                 0.016854
# 3                    0.127137                 0.029998
# 4                    0.031204                 0.021185
#
#    question_type_reason_explanation  question_type_spelling  \
# 0                          0.149550                0.000356
# 1                          0.050171                0.000003
# 2                          0.115770                0.000321
# 3                          0.135465                0.000010
# 4                          0.135805                0.000151
#
#    question_well_written
# 0               0.171178
# 1               0.156384
# 2               0.177922
# 3               0.167081
# 4               0.169942
#
# [5 rows x 31 columns]

# %%
submission.head()
# Out:
#    qa_id  answer_helpful  answer_level_of_information  answer_plausible  \
# 0     39        0.893574                     0.647638          0.938963
# 1     46        0.974232                     0.645259          0.986066
# 2     70        0.903463                     0.631591          0.962961
# 3    132        0.935730                     0.708197          0.973837
# 4    200        0.943380                     0.689623          0.976873
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0          0.949405             0.841590                  0.020867
# 1          0.977809             0.874709                  0.836266
# 2          0.964338             0.831370                  0.170114
# 3          0.980762             0.851305                  0.666206
# 4          0.978851             0.896006                  0.021591
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.077992                        0.656593             0.918596
# 1               0.123572                        0.370142             0.903319
# 2               0.085045                        0.769013             0.924618
# 3               0.170964                        0.660033             0.897477
# 4               0.067137                        0.614632             0.924365
#
#    ...  question_type_choice  question_type_compare  \
# 0  ...              0.560883               0.206260
# 1  ...              0.290577               0.002549
# 2  ...              0.622739               0.037902
# 3  ...              0.190207               0.038406
# 4  ...              0.461461               0.013444
#
#    question_type_consequence  question_type_definition  question_type_entity  \
# 0                   0.007055                  0.066064              0.101515
# 1                   0.002014                 -0.014330              0.023851
# 2                   0.016676                  0.185005              0.006319
# 3                   0.000202                 -0.012174              0.040113
# 4                   0.009511                  0.063459             -0.010598
#
#    question_type_instructions  question_type_procedure  \
# 0                    0.067022                 0.107158
# 1                    0.749636                 0.233961
# 2                    0.233942                 0.063845
# 3                    0.589872                 0.123979
# 4                    0.033178                 0.108666
#
#    question_type_reason_explanation  question_type_spelling  \
# 0                          0.627412                0.001137
# 1                          0.261866               -0.000018
# 2                          0.616816                0.002589
# 3                          0.482448                0.000725
# 4                          0.672514               -0.000227
#
#    question_well_written
# 0               0.891387
# 1               0.808878
# 2               0.882085
# 3               0.793409
# 4               0.825439
#
# [5 rows x 31 columns]

# %%
submission = pd.DataFrame()
submission["qa_id"]=test["qa_id"]
for col_index, col in enumerate(targets):
    submission[col]=test_pred[col_index]

# %%
submission.head()
# Out:
#    qa_id  answer_helpful  answer_level_of_information  answer_plausible  \
# 0     39        0.907015                     0.667845          0.946907
# 1     46        0.946293                     0.660090          0.982847
# 2     70        0.903839                     0.629932          0.953621
# 3    132        0.968164                     0.685778          0.969396
# 4    200        0.951732                     0.715292          0.981925
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0          0.949878             0.879090                  0.196009
# 1          0.982777             0.865891                  0.759453
# 2          0.963978             0.815442                  0.300312
# 3          0.979191             0.895952                  0.704249
# 4          0.979827             0.895551                  0.056511
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.084466                        0.732220             0.911234
# 1               0.089829                        0.415692             0.899201
# 2               0.111462                        0.755992             0.906627
# 3               0.191413                        0.642183             0.912134
# 4               0.058340                        0.689481             0.910306
#
#    ...  question_type_choice  question_type_compare  \
# 0  ...              0.411267               0.061102
# 1  ...              0.393885               0.008511
# 2  ...              0.575582               0.068988
# 3  ...              0.101201               0.012611
# 4  ...              0.476388               0.042478
#
#    question_type_consequence  question_type_definition  question_type_entity  \
# 0                   0.009921                  0.060283              0.125330
# 1                  -0.002437                  0.005525              0.001269
# 2                   0.020585                  0.154319              0.018099
# 3                   0.012461                 -0.008992              0.096137
# 4                   0.012318                  0.041211              0.070355
#
#    question_type_instructions  question_type_procedure  \
# 0                    0.097357                 0.168120
# 1                    0.811663                 0.246351
# 2                    0.200590                 0.058795
# 3                    0.700689                 0.121406
# 4                    0.171764                 0.140981
#
#    question_type_reason_explanation  question_type_spelling  \
# 0                          0.547579               -0.000435
# 1                          0.202738                0.000357
# 2                          0.621828                0.000790
# 3                          0.466026               -0.000319
# 4                          0.563250               -0.000315
#
#    question_well_written
# 0               0.894062
# 1               0.843483
# 2               0.893175
# 3               0.720806
# 4               0.854286
#
# [5 rows x 31 columns]

# %%
# Correct Transposed
submission.head()
# Out:
#    qa_id  answer_helpful  answer_level_of_information  answer_plausible  \
# 0     39        0.907015                     0.667845          0.946907
# 1     46        0.946293                     0.660090          0.982847
# 2     70        0.903839                     0.629932          0.953621
# 3    132        0.968164                     0.685778          0.969396
# 4    200        0.951732                     0.715292          0.981925
#
#    answer_relevance  answer_satisfaction  answer_type_instructions  \
# 0          0.949878             0.879090                  0.196009
# 1          0.982777             0.865891                  0.759453
# 2          0.963978             0.815442                  0.300312
# 3          0.979191             0.895952                  0.704249
# 4          0.979827             0.895551                  0.056511
#
#    answer_type_procedure  answer_type_reason_explanation  answer_well_written  \
# 0               0.084466                        0.732220             0.911234
# 1               0.089829                        0.415692             0.899201
# 2               0.111462                        0.755992             0.906627
# 3               0.191413                        0.642183             0.912134
# 4               0.058340                        0.689481             0.910306
#
#    ...  question_type_choice  question_type_compare  \
# 0  ...              0.411267               0.061102
# 1  ...              0.393885               0.008511
# 2  ...              0.575582               0.068988
# 3  ...              0.101201               0.012611
# 4  ...              0.476388               0.042478
#
#    question_type_consequence  question_type_definition  question_type_entity  \
# 0                   0.009921                  0.060283              0.125330
# 1                  -0.002437                  0.005525              0.001269
# 2                   0.020585                  0.154319              0.018099
# 3                   0.012461                 -0.008992              0.096137
# 4                   0.012318                  0.041211              0.070355
#
#    question_type_instructions  question_type_procedure  \
# 0                    0.097357                 0.168120
# 1                    0.811663                 0.246351
# 2                    0.200590                 0.058795
# 3                    0.700689                 0.121406
# 4                    0.171764                 0.140981
#
#    question_type_reason_explanation  question_type_spelling  \
# 0                          0.547579               -0.000435
# 1                          0.202738                0.000357
# 2                          0.621828                0.000790
# 3                          0.466026               -0.000319
# 4                          0.563250               -0.000315
#
#    question_well_written
# 0               0.894062
# 1               0.843483
# 2               0.893175
# 3               0.720806
# 4               0.854286
#
# [5 rows x 31 columns]

# %%
submission=submission.apply(lambda x: round(abs(x),5))

# %%
submission.min()
# Out:
# qa_id                                    39.00000
# answer_helpful                            0.82745
# answer_level_of_information               0.59557
# answer_plausible                          0.85238
# answer_relevance                          0.91885
# answer_satisfaction                       0.76846
# answer_type_instructions                  0.00590
# answer_type_procedure                     0.02850
# answer_type_reason_explanation            0.08064
# answer_well_written                       0.82341
# question_asker_intent_understanding       0.75739
# question_body_critical                    0.34934
# question_conversational                   0.00001
# question_expect_short_answer              0.40398
# question_fact_seeking                     0.44813
# question_has_commonly_accepted_answer     0.22907
# question_interestingness_others           0.48563
# question_interestingness_self             0.37807
# question_multi_intent                     0.03764
# question_not_really_a_question            0.00000
# question_opinion_seeking                  0.13499
# question_type_choice                      0.00295
# question_type_compare                     0.00006
# question_type_consequence                 0.00005
# question_type_definition                  0.00009
# question_type_entity                      0.00013
# question_type_instructions                0.00462
# question_type_procedure                   0.03253
# question_type_reason_explanation          0.00285
# question_type_spelling                    0.00000
# question_well_written                     0.61886
# dtype: float64

# %%
submission.min()
# Out:
# qa_id                                    39.00000
# answer_helpful                            0.83730
# answer_level_of_information               0.56156
# answer_plausible                          0.84660
# answer_relevance                          0.91574
# answer_satisfaction                       0.74703
# answer_type_instructions                  0.00319
# answer_type_procedure                     0.00650
# answer_type_reason_explanation            0.02822
# answer_well_written                       0.82855
# question_asker_intent_understanding       0.77930
# question_body_critical                    0.35172
# question_conversational                   0.00004
# question_expect_short_answer              0.34206
# question_fact_seeking                     0.45699
# question_has_commonly_accepted_answer     0.22513
# question_interestingness_others           0.47585
# question_interestingness_self             0.37349
# question_multi_intent                     0.00997
# question_not_really_a_question            0.00001
# question_opinion_seeking                  0.13432
# question_type_choice                      0.00060
# question_type_compare                     0.00001
# question_type_consequence                 0.00004
# question_type_definition                  0.00004
# question_type_entity                      0.00021
# question_type_instructions                0.00139
# question_type_procedure                   0.01307
# question_type_reason_explanation          0.00662
# question_type_spelling                    0.00000
# question_well_written                     0.60499
# dtype: float64

# %%
val_y.values[:,0]
# Out:
# array([0.66666667, 1.        , 1.        , ..., 0.88888889, 1.        ,
#        1.        ])

# %%
# Compatible with tensorflow backend
class SpearmanRhoCallback(Callback):
    def __init__(self, training_data, validation_data, patience, model_name):
        self.x = training_data[0]
        self.y = training_data[1]
        self.x_val = validation_data[0]
        self.y_val = validation_data[1]
        
        self.patience = patience
        self.value = -1
        self.bad_epochs = 0
        self.model_name = model_name

    def on_train_begin(self, logs={}):
        return

    def on_train_end(self, logs={}):
        return

    def on_epoch_begin(self, epoch, logs={}):
        return

    def on_epoch_end(self, epoch, logs={}):
        y_pred_val = self.model.predict(self.x_val)
        rho_val = np.mean([spearmanr(self.y_val[:, ind], y_pred_val[:, ind] + np.random.normal(0, 1e-7, y_pred_val.shape[0])).correlation for ind in range(y_pred_val.shape[1])])
        if rho_val >= self.value:
            self.value = rho_val
        else:
            self.bad_epochs += 1
        if self.bad_epochs >= self.patience:
            print("Epoch %05d: early stopping Threshold" % epoch)
            self.model.stop_training = True
            #self.model.save_weights(self.model_name)
        print('\rval_spearman-rho: %s' % (str(round(rho_val, 4))), end=100*' '+'\n')
        return rho_val

    def on_batch_begin(self, batch, logs={}):
        return

    def on_batch_end(self, batch, logs={}):
        return
